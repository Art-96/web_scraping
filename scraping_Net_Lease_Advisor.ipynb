# %%
from bs4 import BeautifulSoup as BS
import builtwith
import pandas as pd
import requests
import re

# %%
builtwith.parse('https://www.netleaseadvisor.com')
# Out:
# {'web-servers': ['Nginx'],
#  'font-scripts': ['Google Font API'],
#  'analytics': ['TrackJs'],
#  'web-frameworks': ['Twitter Bootstrap'],
#  'cms': ['WordPress'],
#  'programming-languages': ['PHP'],
#  'blogs': ['PHP', 'WordPress'],
#  'javascript-frameworks': ['jQuery', 'jQuery UI']}

# %%
url=('https://www.netleaseadvisor.com/tenant/checkers/')

# %%
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)\
Chrome/80.0.3987.116 Safari/537.36', 'accept': '*/*'}

# %%
html=requests.get(url, headers=headers)

# %%
soup=BS(html.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    CheckersNet Lease Advisor | Net Lease Advisor
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php" rel="pingback"/>
#   <!-- All in One SEO Pack 3.3.5 by Michael Torbert of Semper Fi Web Designob_start_detected [-1,-1] -->
#   <script class="aioseop-schema" type="application/ld+json">
#    {}
#   </script>
#   <link href="https://www.netleaseadvisor.com/tenant/checkers/" rel="canonical"/>
#   <!-- All in One SEO Pack -->
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://www.netleaseadvisor.com/feed/" rel="alternate" title="Net Lease Advisor » Feed" type="application/rss+xml"/>
#   <link href="https://www.netleaseadvisor.com/comments/feed/" rel="alternate" title="Net Lease Advisor » Comments Feed" type="application/rss+xml"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.netleaseadvisor.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.3.2"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
#   </script>
#   <style type="text/css">
#    img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-includes/css/dist/block-library/style.min.css?ver=5.3.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.css?ver=5.3.2" id="jquery-ui-timepicker-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/css/dsc-style.css?ver=5.3.2" id="dsc-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/css/settings.css?ver=5.3.0.2" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="rs-plugin-settings-inline-css" type="text/css">
#    #rs-demo-id {}
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.13-9993131" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=5.3.2" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/bootstrap.min.css?ver=5.3.2" id="lambda-bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/theme.min.css?ver=5.3.2" id="lambda-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda-child-theme/style.css?ver=5.3.2" id="lambda-child-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/lambda/stack-90.css?ver=5.3.2" id="lambda-theme-stack-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/css/wpb_wmca_style.css?ver=1.0" id="wpb_wmca_accordion_style-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="//www.google.com/jsapi?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/js/dynamic-stock-charts.min.js?ver=1.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.tools.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.revolution.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/Chart.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <link href="https://www.netleaseadvisor.com/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <link href="https://www.netleaseadvisor.com/tenant/olive-garden/" rel="prev" title="Olive Garden"/>
#   <meta content="WordPress 5.3.2" name="generator"/>
#   <link href="https://www.netleaseadvisor.com/?p=1339" rel="shortlink"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fcheckers%2F" rel="alternate" type="application/json+oembed"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fcheckers%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#   <!-- This site is using AdRotate v5.4.2 Professional to display their advertisements - https://ajdg.solutions/products/adrotate-for-wordpress/ -->
#   <!-- AdRotate CSS -->
#   <style media="screen" type="text/css">
#    .g { margin:0px; padding:0px; overflow:hidden; line-height:1; zoom:1; }
# 	.g img { height:auto; }
# 	.g-col { position:relative; float:left; }
# 	.g-col:first-child { margin-left: 0; }
# 	.g-col:last-child { margin-right: 0; }
# 	@media only screen and (max-width: 480px) {
# 		.g-col, .g-dyn, .g-single { width:100%; margin-left:0; margin-right:0; }
# 	}
#   </style>
#   <!-- /AdRotate CSS -->
#   <style type="text/css">
#    .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#   </style>
#   <meta content="Powered by Visual Composer - drag and drop page builder for WordPress." name="generator"/>
#   <!--[if lte IE 9]><link rel="stylesheet" type="text/css" href="https://www.netleaseadvisor.com/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css" media="screen"><![endif]-->
#   <!--[if lte IE 8]><script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/excanvas.compiled.js"></script><![endif]-->
#   <style>
#    /*wp_charts_js responsive canvas CSS override*/
#     			.wp_charts_canvas {
#     				width:100%!important;
#     				max-width:100%;
#     			}
#
#     			@media screen and (max-width:480px) {
#     				div.wp-chart-wrap {
#     					width:100%!important;
#     					float: none!important;
# 						margin-left: auto!important;
# 						margin-right: auto!important;
# 						text-align: center;
#     				}
#     			}
#   </style>
#   <meta content="Powered by Slider Revolution 5.3.0.2 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." name="generator"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-150x150.png" rel="icon" sizes="32x32"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="icon" sizes="192x192"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" name="msapplication-TileImage"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto:100,300,300italic,400,400italic,500,700,700italic%7CRoboto+Condensed:300,400,700%7CCutive:400%7CRoboto+Slab:100,300,400,700&amp;subset=latin,latin,latin,latin" rel="stylesheet" type="text/css"/>
#   <style media="screen" type="text/css">
#    .tenant-news-title {
#     font-family: Roboto, sans-serif;
#     font-weight: bold;
#     line-height: 18px;
#     margin-bottom: -4px;
# }
# span.tenant-news-date {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# span.tenant-news-source {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# .eh-section {
#   margin-top: -15px;
# }
# .eh-title {
#     font-size: 18px;
#     font-weight: bold;
#     color: #F18F1F;
#     margin-top: -5px;
#     margin-bottom: 11px;
#     line-height: 20px;
# }
# .eh-bullets {
#  padding-bottom: 10px;
# }
# .eh-buttons a i {
#     margin-left: 0px !important;
#     padding-right: 5px !important;
#     font-size: 18px;
#     position: relative;
#     top: 1px;
# }
#
# .eh-buttons a {
# background: #00205B !important;
# font-weight: bold;
# margin-top: -3px;
# }
# .eh-buttons a:hover {
# background: #f18f1f !important;
# }
#
# /* Sidebar Contact Us button hover fix */
# .sidebar-contact-btn.btn.btn-block.btn-success:hover {
#     background-color: #f18f1f !important;
# }
# /* SCUBHF END */
#
# /* Sector Button Hover Fix */
# .selector-buttons:hover {
#     background-color: #f18f1f;
# }
# /* SBHF END */
#
# /* Credit Rating Nav item fix */
# .menu-item-523.active a:hover, .current-menu-item.menu-item-523 a:hover {
#     color: #00205B !important;
# }
# .menu-item-523.active a, .current-menu-item.menu-item-523 a{
#     color: #FFFFFF !important;
# }
# /* CRNIF END */
# .powered-by {
#     margin-left: -100px;
#     margin-bottom: -32px;
# }
#
# .dsc-loader {
#
#     position: relative !important;
#     top: 140px !important;
#
# }
#
# .wpcf7-mail-sent-ok {
#  color: #00205b !important;
#  font-weight: bold !important;
# font-size: 18px !important;
# }
#
# .btn {
#   border-radius: 5px !important;
# }
#
# .tenant-snapshot {
# 	color: #8C8279;
# 	font-size: 22px;
#         line-height: 38px;
# 	margin-top: 4px;
# 	margin-bottom: -1px;
#
# }
#
# .tenant-snapshot .tenant-name {
# 	color: #00205b;
# 	font-size: 40px;
# 	/* position: relative;
#         top: 6px; */
# }
#
# @media (max-width: 700px) {
#
# .tenant-logo {
#     height: 75px !important;
#     width: 100% !important;
#     margin-bottom: 25px !important;
# }
# .tenant-logo img {
#     position: inherit !important;
# }
#
# }
#
# /* Stock Chart Tooltip Style */
# .google-visualization-tooltip .dsc-tooltip caption {
#     font-size: 18px;
#     padding: 0;
# }
# .google-visualization-tooltip .dsc-tooltip td.label {
#     width: auto;
#     color: #F18F1F;
#     text-align: right;
#     padding-right: 5px;
# }
#
# /* Site Width Settings */
# @media (min-width: 1200px) and (max-width: 1414px){
#      .container {
#         width: 1200px !important;
#     }
#
# .featured-thumb a img {
#     width: 65px;
# }
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 17px;
#     font-weight: bold;
#     color: #8c8279;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-desc {
#     float: left;
#     margin-left: 10px;
#     line-height: 18px;
# }
# }
#
# @media (min-width: 1415px){
#     .container {
#         width: 1400px !important;
#     }
# }
# @media (min-width: 768px){
#     .container {
#         width: 100%;
#     }
# }
# a.tenant-detail-link.btn.btn-success, .sidebar-contact-btn {
#     background: #00205B !important;
#     border-radius: 5px !important;
#     font-size: 20px;
#     padding: 7px 30px;
#     margin: 20px auto;
#     font-weight: bold;
#     text-transform: uppercase;
# }
# a.tenant-detail-link.btn.btn-success:hover, .sidebar-contact-btn:hover {
#     background-color: #f18f1f !important;
# }
# .table-striped > tbody > tr:nth-child(odd) > td, .table-striped > tbody > tr:nth-child(odd) > th, .table-hover > tbody > tr:hover > td, .table-hover > tbody > tr:hover > th {
#     background: rgb(243, 243, 243);
# }
#
# section.section.tenant > .container > .row {
#     padding-bottom: 30px;
# }
#
# /* HOMEPAGE FEATURED TENANTS */
#
# .featured-single-wrapper {
#     width: 100%;
#     margin-top: 10px;
#     margin-bottom: 10px;
# }
#
# .featured-thumb {
#     float: left;
# }
#
# .featured-thumb a img {
#     width: 65px;
# }
#
# .featured-desc {
#     float: left;
#     margin-left: 15px;
#     line-height: 18px;
# }
#
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 20px;
#     font-weight: bold;
#     color: #8C8279;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-tenants > .post-title {
#     padding-top: 30px;
# }
#
# .featured-sector, .featured-cap {
#     font-size: 14px;
# }
#
# .featured-sector span, .featured-cap span {
#     font-weight: bold;
# }
#
# /* HEADER TAGLINE */
#
# .tagline {
# 	font-family: "Roboto Condensed" !important;
# 	font-weight: bold !important;
# 	font-size: 20px !important;
# 	color: #fff !important;
#         text-align: right !important;
# }
#
# /* SIDEBAR ACCORDION */
#
# .selector-buttons {
#     width: 100%;
#     margin: 30px 0;
#     padding: 10px;
#     font-size: 18px;
#     font-weight: bold;
#     background-color: #00205B;
# }
#
# @media (min-width: 992px) and (max-width: 1199px){
#
#     .selector-buttons {
#         font-size: 16px;
#         padding: 10px 5px;
#     }
#
# }
#
# .sidebar-toggle {
#     display:none;
# }
#
# @media (max-width: 991px) {
#     .col-md-3.sidebar .sidebar-collapse-control-btn {
#         position: absolute;
#         top: -1px;
#         left: -55px;
#         width: 55px;
#         height: 45px;
#         background-color: #00205B;
#         border-top-left-radius: 5px;
#         border-bottom-left-radius: 5px;
#     }
#     .sidebar-collapse-control-btn button.navbar-toggle.collapsed {
#         margin: 14px 15px;
#     }
#     .col-md-3.sidebar {
#         position: absolute;
#         top: -65px;
#         right: -300px;
#         width: 300px;
#         background-color: #f18f1f3;
#         border: 1px solid #f18f1f3;
#     }
#
#
# .sidebar-toggle {
#     display: block;
#     background: none !important;
#     margin: 14px 17px;
#     width: 22px;
#     height: 16px;
#     border: none;
#     transform: translate3d(0,0,0);
# }
#
# .sidebar-toggle .icon-bar:nth-child(1) {
#     top: 0;
# }
#
# .sidebar-toggle .icon-bar {
#     background-color: #fff;
# }
#
# .sidebar-toggle .icon-bar {
#     height: 1px;
#     width: 100%;
#     position: absolute;
#     left: 0;
#     margin-top: 0!important;
#     transition: all .3s;
#     -ms-transform-origin: 50% 50% 50%;
#     transform-origin: 50% 50% 50%;
#     transform: translate3d(0,0,0);
#     box-shadow: none;
# }
#
# .sidebar-toggle .icon-bar {
#     display: block;
#     width: 22px;
#     height: 1px;
#     border-radius: 1px;
# }
#
# .sidebar-toggle .icon-bar:nth-child(3) {
#     top: 100%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(2) {
#     opacity: 0;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(1) {
#     -ms-transform: rotate(45deg);
#     transform: rotate(45deg);
#     top: 50%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(3) {
#     top: 50%;
#     -ms-transform: rotate(-45deg);
#     transform: rotate(-45deg);
# }
#
# [class*="col-"].sidebar {
#     margin-bottom: auto !important;
#     padding-bottom: 0 !important;
# }
#
# .selector-buttons:hover {
#     background-color: #00205B;
# }
# }
#
# .ui-accordion h3 {
#    margin-top: 0;
#     margin-bottom: 0px;
#     padding-top: 1px;
#     padding-bottom: 1px;
#     padding-left: 3px;
# }
# .ui-accordion h3:hover {
#     background-color: #F18F1F;
#     color: #FFFFFF;
#     cursor: pointer;
# }
# li.accordion-list-item {
#     list-style: none;
#     border-bottom: 1px solid #84919f;
#     margin-left: 0px;
#     padding-left: 5px;
# }
# a li.accordion-list-item {
#     font-size: 16px;
# }
#
# li.accordion-list-item:hover {
#     background-color: #F18F1F;
#     color: #FFF;
#     cursor: pointer;
# }
#
# a li.accordion-list-item:hover {
#     color: #00205b;
#     cursor: pointer;
# }
#
# li.accordion-list-item.active-tenant {
#     background-color: #00205B;
#     padding-left: 5px;
#     margin-left: 0px;
# }
#
# a li.accordion-list-item.active-tenant {
#     color: #FFF;
# }
#
# /* AD AREAS */
# .banner-ad-wrapper {
#     padding: 50px 0;
#     text-align: center;
# }
#
# h3.sidebar-header {
#     text-transform: initial;
#     font-size: 24px;
#     border-bottom: 1px solid #84919f;
#     margin-bottom: 1px;
# }
# ul.tenant-list-ucr {
#     list-style: none;
#     padding: 0px;
#     margin: 0px;
# }
# li.tlucr-item {
#     border-bottom: 1px solid #84919f;
#     margin-left: 5px;
#     font-size: 16px;
# }
# .squeeze {
#     line-height: 1.5em !important;
# }
# /* SINGLE TENANT PAGE */
#
# .sidebar {
#     background-color: rgba(234, 233, 233, 0.55);
# }
#
# .tenant h1.post-title {
#     font-size: 35px;
#     font-weight: bold;
#     margin-top: 0px;
# }
#
# .header-updated-hr {
#     border-color: #F18F1F;
#     margin: -10px 0 3px;
# }
# .tenant-logo-home {
#     right: 15px;
#     top: 4px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# .tenant-logo {
#     right: 15px;
#     top: 8px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# @media (max-width: 991px){
#     .tenant-logo {
#         margin-right: 55px;
#     }
# }
# @media (max-width: 1414px){
#  .tenant h1.post-title {
#     font-size: 26px;
#     font-weight: bold;
#     margin-top: 40px;
# }
# }
# .tenant-logo  img {
#     max-width: 100%;
#     position: absolute;
#     bottom: 0;
#     right: 0;
# }
# .detail-box .detail-head {
#     background-color: #00205b;
#     color: #fff;
#     text-transform: normal;
#     font-size: 18px;
#     padding: 2px 10px;
#     text-align: right;
#     font-weight: 400;
# }
# .detail-large-data {
#     text-align: right;
#     font-size: 78px;
#     line-height: 85px;
#     font-weight: bold;
#     color: #f18f1f;
# }
# .detail-sm-desc {
#     font-size: 13px;
#     text-align: right;
#     clear: both;
# }
# .detail-box {
#     margin-bottom: 25px;
# }
# .detail-data-table tr td {
#     padding-top: 5px !important;
#     padding-bottom: 5px !important;
# }
# .tenant-url-link {
#     margin-bottom: 15px;
# }
# .tenant-url-link a {
#     color: #F18F1F;
#     font-size: 16px;
#     font-weight: bold;
# }
# .tenant-url-link a:hover {
#     text-decoration: underline;
# }
# .tenant-stock-chart {
#     margin: 15px 0 30px;
#     margin-top: -20px;
# }
# .dschart {
#       margin-top: -20px;
# }
# td.data-label {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#     font-weight: 400;
#     line-height: 18px !important;
# }
# td.data-data {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#    font-weight: 400;
#     line-height: 18px !important;
# }
#
# .credit-rating td.data-label, .credit-rating td.data-data {
#     line-height: 22px !important;
#     width: 50%;
#     text-align: right;
#     font-size: 36px;
#     font-weight: bold;
#     color: #f18f1f;
#     padding: 10px 0 !important;
#  }
# .pros > h3, .cons > h3 {
#    padding-left: 11px;
# }
# .pro-item, .con-item, .eh-item {
#      font-size: 16px;
#      line-height: 20px;
#      margin-bottom: .8em;
# }
# .trend-info {
#     width: 33%;
#     float: left;
#     text-align: center;
#     margin-top: 8px;
# }
# .trend-year {
#     font-size: 18px;
#     color: #00205b;
#     margin-top: -15px;
# }
# .trend-rate {
#     font-size: 28px;
#     font-weight: bold;
#     color: #00205b;
# }
# .trend-image {
# width: 34%;
#     float: left;
#     text-align: center;
# }
# .tenant-description p {
#     font-size: 16px;
# }
# .tenant-description a {
# color: #f18f1f;
# }
# li.accordion-list-item.active {
#     background-color: #f18f1f;
# }
# li.accordion-list-item.active a {
#     color: #FFF;
# }
#
# /* MODAL */
# .modal-title {
#      font-size: 24px;
#      line-height: 24px;
# }
# .modal-body {
#     font-size: 14px;
#     line-height: 18px;
# }
# .modal-body a {
#     color: #f18f1f;
# }
# .modal-header {
#     border-bottom: 1px solid #f18f1f;
# }
# /* NET LEASE 101 */
# .caption-text {
# 	font-size: 16px;
# 	line-height: 1.4em;
# }
# .caption-head {
# 	font-family: Roboto Condensed, sans-serif;
# 	font-size: 21px;
# 	font-weight: bold;
# 	color: #00205b;
# }
#
# /*OTHER*/
# i {
#   color: #00205B !important;
# }
# .post-date {
#     font-size: 12px !important;
#     position: relative;
#     top: -2px !important;
#     font-style: italic;
#     color: #8c8279;
#     text-align: right;
# }
#
# #footer {
#   font-size: 14px;
# }
# .row:not(.sidebar-row){
#     overflow: hidden;
# }
#
# [class*="col-"].sidebar{
#     margin-bottom: -99999px;
#     padding-bottom: 99999px;
# }
#
# .subfooter {
#   text-align: center;
#   font-weight: 300;
# }
# .subfooter a {
#   font-weight: 400;
# }
#   </style>
#   <script type="text/javascript">
#    var lhnAccountN = "36965-1";
#     var lhnButtonN = 9229;
#     var lhnChatPosition = 'default';
#     var lhnInviteEnabled = 1;
#     var lhnWindowN = 0;
#     var lhnDepartmentN = 44047;
#     var lhnInviteN = 43001;
#   </script>
#   <noscript>
#    <style type="text/css">
#     .wpb_animate_when_almost_visible { opacity: 1; }
#    </style>
#   </noscript>
#  </head>
#  <body class="tenant-template-default single single-tenant postid-1339 wpb-js-composer js-comp-ver-5.0 vc_responsive">
#   <div class="pace-overlay">
#   </div>
#   <div class="menu navbar navbar-static-top header-logo-left-menu-below oxy-mega-menu navbar-sticky navbar-not-mobile-stuck text-none" id="masthead" role="banner">
#    <div class="logo-navbar container-logo">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle collapsed" data-target=".main-navbar" data-toggle="collapse" type="button">
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a class="navbar-brand" href="https://www.netleaseadvisor.com">
#        <img alt="Net Lease Advisor" src="https://www.netleaseadvisor.com/wp-content/uploads/2020/02/Net-Lease-Advisor-Logo-AY-Left-Justified.png"/>
#       </a>
#       <div class="logo-sidebar">
#        <div class="sidebar-widget widget_text" id="text-7">
#         <div class="textwidget">
#          <div class="powered-by">
#           Powered by
#          </div>
#          <div>
#           <a href="http://www.avisonyoung.com" rel="nofollow">
#            <img src="https://www.netleaseadvisor.com/wp-content/uploads/2020/02/AY_LOGO_WHITE_150w.png" width="75px"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="nav-container clearfix">
#      <nav class="collapse navbar-collapse main-navbar navbar-left" role="navigation">
#       <div class="menu-container">
#        <ul class="nav navbar-nav" id="menu-main">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-66" id="menu-item-66">
#          <a href="https://www.netleaseadvisor.com/">
#           HOME
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-728" id="menu-item-728">
#          <a href="https://www.netleaseadvisor.com/net-lease-101/">
#           NET LEASE 101
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-523" id="menu-item-523">
#          <a data-target="#521" data-toggle="modal" href="#">
#           CREDIT RATINGS
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-518" id="menu-item-518">
#          <a href="https://www.netleaseadvisor.com/contact/">
#           CONTACT
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="menu-sidebar">
#       </div>
#      </nav>
#     </div>
#    </div>
#   </div>
#   <div id="content" role="main">
#    <section class="section tenant">
#     <div class="container">
#      <div class="row">
#       <div class="col-md-9">
#        <p style="height: 45px;">
#        </p>
#        <article class="post-1339 tenant type-tenant status-publish has-post-thumbnail hentry sector-qsr" id="post-1339">
#         <h1 class="post-title">
#          Checkers TENANT OVERVIEW
#         </h1>
#         <div class="tenant-logo">
#          <img src="https://www.netleaseadvisor.com/wp-content/uploads/2019/12/Checkers-Logo-newest.jpg"/>
#         </div>
#         <hr class="header-updated-hr"/>
#         <div class="post-date">
#          Updated: December 19, 2019
#         </div>
#         <div class="row">
#          <div class="col-md-8">
#           <div class="figure fade-in text-center figcaption-middle">
#            <img alt="" class="attachment-large size-large wp-post-image" height="364" sizes="(max-width: 800px) 100vw, 800px" src="https://www.netleaseadvisor.com/wp-content/uploads/2019/12/Checkers_NLA_Featured-800x364.jpg" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2019/12/Checkers_NLA_Featured-800x364.jpg 800w, https://www.netleaseadvisor.com/wp-content/uploads/2019/12/Checkers_NLA_Featured-300x136.jpg 300w, https://www.netleaseadvisor.com/wp-content/uploads/2019/12/Checkers_NLA_Featured-768x349.jpg 768w, https://www.netleaseadvisor.com/wp-content/uploads/2019/12/Checkers_NLA_Featured.jpg 1451w" width="800"/>
#           </div>
#           <div class="pros_cons row">
#            <div class="pros col-md-6">
#             <h3>
#              Pros
#             </h3>
#             <ul class="pros-list">
#              <li class="pro-item">
#               NNN leases
#              </li>
#              <li class="pro-item">
#               Long-term tenant
#              </li>
#              <li class="pro-item">
#               Well-known chain
#              </li>
#             </ul>
#            </div>
#            <div class="cons col-md-6">
#             <h3>
#              Cons
#             </h3>
#             <ul class="cons-list">
#              <li class="con-item">
#               Smaller footprint than QSR competition
#              </li>
#              <li class="con-item">
#               Competitive sector
#              </li>
#              <li class="con-item">
#               Privately held
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="tenant-description">
#            <h2>
#             Tenant Description
#            </h2>
#            <p>
#             Checkers is a drive-in chain dedicated to serving American classics for competitive prices.
#             <br/>
#             <br/>
#             Originally different companies, Checkers was founded in 1986 in Mobile, Alabama, while Rally’s was founded in 1985 in Louisville, Kentucky. In 1999, CKE Restaurants decided to sell the Rally’s brand to Checkers which merged the two drive-through chains into one single entity. Most recently, Checkers was sold to Oak Hill Capital Partners in March of 2017, where it is currently still under private ownership.
#             <br/>
#             <br/>
#             The names used are currently being split by regions, with Checkers being used mainly in the Southeast along with the Northeast, while the Rally’s brand is used in the Midwest and California. Currently headquartered in Tampa, FL, Checkers currently has about 900 locations.
#             <br/>
#             <br/>
#             Checkers locations are ideal for someone looking to invest in the net lease market as they are NNN leases, alleviating the ownership of maintaining the structure and lot, and will have a longer-term length on their lease, usually 20 years. These leases will also feature built-in escalations to help protect against inflation. Properties are positioned with maximum exposure to through traffic along with ease of access. Buildings do follow a unique layout as well, usually under 1,000 SF, which does limit the ability to find a replacement tenant should Checkers vacate the building upon lease expiration.
#             <br/>
#            </p>
#           </div>
#           <div class="tenant-url-link">
#            <a href="http://www.checkers.com" target="_blank">
#             www.checkers.com
#            </a>
#           </div>
#          </div>
#          <div class="col-md-4">
#           <div class="detail-box">
#            <div class="detail-head">
#             Average Cap Rate
#            </div>
#            <div class="detail-large-data">
#             6.20%
#            </div>
#            <div class="detail-sm-desc">
#             12 mo avg with 10+ yr lease term
#            </div>
#           </div>
#           <div class="detail-box average-property-lease">
#            <div class="detail-head">
#             Average Property &amp; Lease
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                Average Sale Price
#               </td>
#               <td class="data-data">
#                $1,058,020
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                NOI
#               </td>
#               <td class="data-data">
#                $68,016
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                $/Square Foot
#               </td>
#               <td class="data-data">
#                $1,110 - $1,320
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Building SF
#               </td>
#               <td class="data-data">
#                800 - 950
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lot Size
#               </td>
#               <td class="data-data">
#                .5 - .75 Acres
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lease Term
#               </td>
#               <td class="data-data">
#                20 Years
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Escalations
#               </td>
#               <td class="data-data">
#                Varies
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Stock Symbol
#               </td>
#               <td class="data-data">
#                N/A
#               </td>
#              </tr>
#             </table>
#            </div>
#           </div>
#           <div class="detail-box credit-rating">
#            <div class="detail-head">
#             Credit Rating
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                S&amp;P
#               </td>
#               <td class="data-data">
#                N/A
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Moody's
#               </td>
#               <td class="data-data">
#                N/A
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc" style="font-style: italic;">
#            </div>
#           </div>
#           <div class="detail-box average-cap-rate-trend">
#            <div class="detail-head">
#             Average Cap Rate Trend
#            </div>
#            <div class="cap-rate-trend-continer">
#             <div class="trend-info">
#              <div class="trend-left">
#               <div class="trend-rate">
#                7.06%
#               </div>
#               <div class="trend-year">
#                2018
#               </div>
#              </div>
#             </div>
#             <div class="trend-image">
#              <img src="/wp-content/plugins/post-accordion-widget-plugin/images/down.png"/>
#             </div>
#             <div class="trend-info">
#              <div class="trend-right">
#               <div class="trend-rate">
#                6.20%
#               </div>
#               <div class="trend-year">
#                2019
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="detail-sm-desc" style="padding-top: 5px;">
#             Rates reflect last 12 mos, short and long-term
#            </div>
#           </div>
#           <div class="detail-box recent-sales-comps">
#            <div class="detail-head">
#             Recent Sales Comps
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Atlanta, GA
#               </td>
#               <td class="data-data">
#                6.00%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Memphis, TN
#               </td>
#               <td class="data-data">
#                6.40%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Lakeland, FL
#               </td>
#               <td class="data-data">
#                6.22%
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc">
#            </div>
#           </div>
#           <div class="detail-box tenant-news">
#            <div class="detail-head">
#             Tenant News
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td>
#                <a href="https://www.reviewjournal.com/business/checkers-restaurants-to-reopen-in-las-vegas-as-rallys-1867207/" target="_blank">
#                 <div class="news-single-wrapper">
#                  <div class="tenant-news-title">
#                   Checkers restaurants to reopen in Las Vegas as Rally’s
#                  </div>
#                  <div class="tenant-news-subtitle">
#                   <span class="tenant-news-date">
#                    October 9, 2019
#                   </span>
#                   -
#                   <span class="tenant-news-source">
#                    Las Vegas Review-Journal
#                   </span>
#                  </div>
#                  <div class="clearfix">
#                  </div>
#                 </div>
#                </a>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="https://www.middlesborodailynews.com/2019/12/13/big-bang-for-your-buck-rallys-franchise-director-excited-to-come-to-region/" target="_blank">
#                 <div class="news-single-wrapper">
#                  <div class="tenant-news-title">
#                   Big bang for your buck: Rally’s Franchise Director excited to come to region
#                  </div>
#                  <div class="tenant-news-subtitle">
#                   <span class="tenant-news-date">
#                    December 13, 2019
#                   </span>
#                   -
#                   <span class="tenant-news-source">
#                    Middlesboro Daily News
#                   </span>
#                  </div>
#                  <div class="clearfix">
#                  </div>
#                 </div>
#                </a>
#               </td>
#              </tr>
#             </table>
#            </div>
#           </div>
#           <div class="detail-box featured-net-lease-listing">
#            <div class="detail-head">
#             Featured Tenant Profiles
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/family-dollar/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/family-dollar-calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/family-dollar/">
#                Family Dollar
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Dollar Store
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                6.62%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/wawa/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/WaWa-Lake-Mary-FL-Calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/wawa/">
#                Wawa
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Convenience Store
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                4.73%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/la-fitness/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2018/01/LA-Fitness-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/la-fitness/">
#                LA Fitness
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Retail
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                6.18%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </article>
#       </div>
#       <div class="col-md-3 sidebar">
#        <div class="sidebar-widget tax_accordion_widget_class" id="tax_accordion_widget-2">
#         <div class="sidebar-collapse-control-btn">
#          <button class="sidebar-toggle offscreen" type="button">
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </button>
#         </div>
#         <div class="container-fluid">
#          <div class="row">
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-sector">
#             SECTOR
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-alpha">
#             A-Z
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="accordion-sector" id="accordion-sector" style="display:none;">
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Automotive
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#             Advance Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/autozone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/autozone/">
#             AutoZone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bridgestone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bridgestone/">
#             Bridgestone/Firestone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/caliber-collision/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/caliber-collision/">
#             Caliber Collision
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">
#             Christian Brothers Automotive
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/jiffy-lube/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/jiffy-lube/">
#             Jiffy Lube
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">
#             Napa Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#             O’Reilly Auto Parts
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Bank
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/bank-of-america/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bank-of-america/">
#             Bank of America
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bbt-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bbt-bank/">
#             BB&amp;T Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">
#             BMO Harris Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/chase-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chase-bank/">
#             Chase Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/pnc-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pnc-bank/">
#             PNC Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/suntrust/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/suntrust/">
#             SunTrust
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/td-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/td-bank/">
#             TD Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#             Wells Fargo
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Big Box
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/hobby-lobby/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hobby-lobby/">
#             Hobby Lobby
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#             Tractor Supply Co.
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/walmart/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walmart/">
#             Walmart
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Casual Dining
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/applebees/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/applebees/">
#             Applebee’s
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bob-evans/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bob-evans/">
#             Bob Evans
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/buffalo-wild-wings/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/buffalo-wild-wings/">
#             Buffalo Wild Wings
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">
#             Chili’s Grill &amp; Bar
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/cracker-barrel/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cracker-barrel/">
#             Cracker Barrel
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/dennys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dennys/">
#             Denny’s
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/hooters/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hooters/">
#             Hooters
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/ihop/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/ihop/">
#             IHOP
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/olive-garden/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/olive-garden/">
#             Olive Garden
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/red-lobster/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/red-lobster/">
#             Red Lobster
#            </li>
#           </a>
# ...
#             Wawa
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#             Wells Fargo
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wendys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wendys/">
#             Wendy’s
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Z
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/zaxbys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/zaxbys/">
#             Zaxby’s
#            </li>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-10">
#         <div class="textwidget">
#          <a href="/bov-request">
#           <img src="http://netleaseadvisor.com/wp-content/uploads/2017/06/ad-calkain-bov.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-8">
#         <h3 class="sidebar-header">
#          Understanding Credit Ratings
#         </h3>
#         <div class="textwidget">
#          <ul class="tenant-list-ucr">
#           <li class="tlucr-item">
#            <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#             View Credit Rating Chart
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="http://www.spratings.com/en_US/understanding-ratings" rel="noopener noreferrer" target="_new">
#             Standard &amp; Poors
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="https://www.moodys.com/Pages/amr002002.aspx" rel="noopener noreferrer" target="_new">
#             Moody's
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-9">
#         <h3 class="sidebar-header">
#          Have a Research Project?
#         </h3>
#         <div class="textwidget">
#          <div class="squeeze">
#           Our experienced team provides unique insight to the net lease industry.  We can provide an in-depth analysis to a specific segment or assess an investment on your behalf.  Let us know your needs.
#          </div>
#          <a href="/contact">
#           <div class="sidebar-contact-btn btn btn-block btn-success">
#            Contact Us
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <footer id="footer" role="contentinfo">
#     <section class="section">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-6">
#          <div class="textwidget">
#           All logos are ©Copyright, ®Registered Trademarks and  courtesy of their respective companies, and are displayed in this website for the sole purpose of brand recognition in tenant labeling.
#           <br/>
#           ©2017-2020 netleaseadvisor.com,
#           <a href="http://avisonyoung.com" rel="nofollow">
#            Avison Young
#           </a>
#           . All Rights Reserved.
#           <br/>
#           2001 K Street, NW | Washington, DC 20006
#  Tel: 888.724.3244
#           <br/>
#           <span style="color:#a0a0a0; font-weight:bold;">
#            Developed by
#           </span>
#           <a href="mailto:mjvdesign@gmail.com?subject=Ref: netleaseadvisor.com">
#            <img alt="MJVdesign" border="0" src="/wp-content/uploads/2017/03/mjvdesign_logo_transp_light.png" style="margin-top: 2px; margin-left: -4px;" title="Email MJVdesign"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="section subfooter">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-11">
#          <div class="textwidget">
#           <a href="http://www.netleaseadvisor.com">
#            Home
#           </a>
#           |
#           <a href="/net-lease-101">
#            Net Lease 101
#           </a>
#           |
#           <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#            Credit Rating Chart
#           </a>
#           |
#           <a href="/contact">
#            Contact
#           </a>
#           |
#           <a href="/bov-request">
#            BOV Request
#           </a>
#           |
#           <a href="https://AvisonYoung.com" rel="nofollow">
#            Avison Young
#           </a>
#           |
#           <a href="https://calkain.com/research" rel="nofollow">
#            Research
#           </a>
#           |
#           <a href="https://calkain.com/properties" rel="nofollow">
#            Properties
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#    </footer>
#   </div>
#   <!-- Fixing the Back to top button -->
#   <script id="lhnscript" src="//www.livehelpnow.net/lhn/widgets/chatbutton/lhnchatbutton-current.min.js" type="text/javascript">
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#   ga('create', 'UA-4933828-6', 'auto');
#
#   ga('send', 'pageview');
#   </script>
#   <div class="modal fade" id="40" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        Subscribe
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        [mc4wp_form]
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="521" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-lg" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CREDIT RATING CHART
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        <img alt="Net Lease Advisor Credit Rating Chart" class="alignnone wp-image-1087 size-full" height="883" sizes="(max-width: 900px) 100vw, 900px" src="https://netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg 900w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-300x294.jpg 300w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-768x753.jpg 768w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-800x785.jpg 800w" width="900"/>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="516" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CONTACT
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        For specific inquiries regarding this website or tenant information, please contact:
#       </p>
#       <p>
#        <strong>
#         Vinky Marolia
#        </strong>
#        <br/>
#        Research Analyst, Calkain Companies
#        <br/>
#        (571) 449-8146
#        <br/>
#        <a href="mailto:research@calkain.com">
#         research@calkain.com
#        </a>
#       </p>
#       <p>
#        For general inquiries or phone numbers and addresses for all of our office locations:
#        <br/>
#        <a href="http://calkain.com/contact/" target="_blank">
#         Contact Calkain
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/accordion.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/post-accordion-widget-plugin/controller.js?ver=9.9" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var click_object = {"ajax_url":"https:\/\/www.netleaseadvisor.com\/wp-admin\/admin-ajax.php"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/adrotate-pro/library/jquery.adrotate.clicktracker.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.netleaseadvisor.com\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.6" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":1,"isRTL":false});});
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/slider.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/button.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-sliderAccess.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.cookie.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.navgoco.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var mejsL10n = {"language":"en","strings":{"mejs.install-flash":"You are using a browser that does not have Flash player enabled or installed. Please turn on your Flash player plugin or download the latest version from https:\/\/get.adobe.com\/flashplayer\/","mejs.fullscreen-off":"Turn off Fullscreen","mejs.fullscreen-on":"Go Fullscreen","mejs.download-video":"Download Video","mejs.fullscreen":"Fullscreen","mejs.time-jump-forward":["Jump forward 1 second","Jump forward %1 seconds"],"mejs.loop":"Toggle Loop","mejs.play":"Play","mejs.pause":"Pause","mejs.close":"Close","mejs.time-slider":"Time Slider","mejs.time-help-text":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.","mejs.time-skip-back":["Skip back 1 second","Skip back %1 seconds"],"mejs.captions-subtitles":"Captions\/Subtitles","mejs.captions-chapters":"Chapters","mejs.none":"None","mejs.mute-toggle":"Mute Toggle","mejs.volume-help-text":"Use Up\/Down Arrow keys to increase or decrease volume.","mejs.unmute":"Unmute","mejs.mute":"Mute","mejs.volume-slider":"Volume Slider","mejs.video-player":"Video Player","mejs.audio-player":"Audio Player","mejs.ad-skip":"Skip ad","mejs.ad-skip-info":["Skip in 1 second","Skip in %1 seconds"],"mejs.source-chooser":"Source Chooser","mejs.stop":"Stop","mejs.speed-rate":"Speed Rate","mejs.live-broadcast":"Live Broadcast","mejs.afrikaans":"Afrikaans","mejs.albanian":"Albanian","mejs.arabic":"Arabic","mejs.belarusian":"Belarusian","mejs.bulgarian":"Bulgarian","mejs.catalan":"Catalan","mejs.chinese":"Chinese","mejs.chinese-simplified":"Chinese (Simplified)","mejs.chinese-traditional":"Chinese (Traditional)","mejs.croatian":"Croatian","mejs.czech":"Czech","mejs.danish":"Danish","mejs.dutch":"Dutch","mejs.english":"English","mejs.estonian":"Estonian","mejs.filipino":"Filipino","mejs.finnish":"Finnish","mejs.french":"French","mejs.galician":"Galician","mejs.german":"German","mejs.greek":"Greek","mejs.haitian-creole":"Haitian Creole","mejs.hebrew":"Hebrew","mejs.hindi":"Hindi","mejs.hungarian":"Hungarian","mejs.icelandic":"Icelandic","mejs.indonesian":"Indonesian","mejs.irish":"Irish","mejs.italian":"Italian","mejs.japanese":"Japanese","mejs.korean":"Korean","mejs.latvian":"Latvian","mejs.lithuanian":"Lithuanian","mejs.macedonian":"Macedonian","mejs.malay":"Malay","mejs.maltese":"Maltese","mejs.norwegian":"Norwegian","mejs.persian":"Persian","mejs.polish":"Polish","mejs.portuguese":"Portuguese","mejs.romanian":"Romanian","mejs.russian":"Russian","mejs.serbian":"Serbian","mejs.slovak":"Slovak","mejs.slovenian":"Slovenian","mejs.spanish":"Spanish","mejs.swahili":"Swahili","mejs.swedish":"Swedish","mejs.tagalog":"Tagalog","mejs.thai":"Thai","mejs.turkish":"Turkish","mejs.ukrainian":"Ukrainian","mejs.vietnamese":"Vietnamese","mejs.welsh":"Welsh","mejs.yiddish":"Yiddish"}};
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=4.2.13-9993131" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-migrate.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/","classPrefix":"mejs-","stretching":"responsive"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var oxyThemeData = {"navbarScrolledPoint":"30","navbarHeight":"100","navbarScrolled":"50","siteLoader":"off","menuClose":"off","scrollFinishedMessage":"No more items to load.","hoverMenu":{"hoverActive":true,"hoverDelay":200,"hoverFadeDelay":200}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/js/theme.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts//js/functions.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/wp-embed.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
links=[link['href'] for link in soup.findAll('a')]

# %%
links
# Out:
# ['https://www.netleaseadvisor.com',
#  'http://www.avisonyoung.com',
#  'https://www.netleaseadvisor.com/',
#  'https://www.netleaseadvisor.com/net-lease-101/',
#  '#',
#  'https://www.netleaseadvisor.com/contact/',
#  'http://www.checkers.com',
#  'https://www.reviewjournal.com/business/checkers-restaurants-to-reopen-in-las-vegas-as-rallys-1867207/',
#  'https://www.middlesborodailynews.com/2019/12/13/big-bang-for-your-buck-rallys-franchise-director-excited-to-come-to-region/',
#  'https://www.netleaseadvisor.com/tenant/family-dollar/',
#  'https://www.netleaseadvisor.com/tenant/family-dollar/',
#  'https://www.netleaseadvisor.com/tenant/wawa/',
#  'https://www.netleaseadvisor.com/tenant/wawa/',
#  'https://www.netleaseadvisor.com/tenant/la-fitness/',
#  'https://www.netleaseadvisor.com/tenant/la-fitness/',
#  'https://www.netleaseadvisor.com/tenant/advance-auto-parts/',
#  'https://www.netleaseadvisor.com/tenant/autozone/',
#  'https://www.netleaseadvisor.com/tenant/bridgestone/',
#  'https://www.netleaseadvisor.com/tenant/caliber-collision/',
#  'https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/',
#  'https://www.netleaseadvisor.com/tenant/jiffy-lube/',
#  'https://www.netleaseadvisor.com/tenant/napa-auto-parts/',
#  'https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/',
#  'https://www.netleaseadvisor.com/tenant/bank-of-america/',
#  'https://www.netleaseadvisor.com/tenant/bbt-bank/',
#  'https://www.netleaseadvisor.com/tenant/bmo-harris-bank/',
#  'https://www.netleaseadvisor.com/tenant/chase-bank/',
#  'https://www.netleaseadvisor.com/tenant/pnc-bank/',
#  'https://www.netleaseadvisor.com/tenant/suntrust/',
#  'https://www.netleaseadvisor.com/tenant/td-bank/',
#  'https://www.netleaseadvisor.com/tenant/wells-fargo/',
#  'https://www.netleaseadvisor.com/tenant/hobby-lobby/',
#  'https://www.netleaseadvisor.com/tenant/tractor-supply-co/',
#  'https://www.netleaseadvisor.com/tenant/walmart/',
#  'https://www.netleaseadvisor.com/tenant/applebees/',
#  'https://www.netleaseadvisor.com/tenant/bob-evans/',
#  'https://www.netleaseadvisor.com/tenant/buffalo-wild-wings/',
#  'https://www.netleaseadvisor.com/tenant/chilis-grill-bar/',
#  'https://www.netleaseadvisor.com/tenant/cracker-barrel/',
#  'https://www.netleaseadvisor.com/tenant/dennys/',
#  'https://www.netleaseadvisor.com/tenant/hooters/',
#  'https://www.netleaseadvisor.com/tenant/ihop/',
#  'https://www.netleaseadvisor.com/tenant/olive-garden/',
#  'https://www.netleaseadvisor.com/tenant/red-lobster/',
#  'https://www.netleaseadvisor.com/tenant/ruby-tuesday/',
#  'https://www.netleaseadvisor.com/tenant/7-eleven/',
#  'https://www.netleaseadvisor.com/tenant/circle-k/',
#  'https://www.netleaseadvisor.com/tenant/sheetz/',
#  'https://www.netleaseadvisor.com/tenant/wawa/',
#  'https://www.netleaseadvisor.com/tenant/dollar-general/',
#  'https://www.netleaseadvisor.com/tenant/dollar-tree/',
#  'https://www.netleaseadvisor.com/tenant/family-dollar/',
#  'https://www.netleaseadvisor.com/tenant/the-learning-experience/',
#  'https://www.netleaseadvisor.com/tenant/aldi/',
#  'https://www.netleaseadvisor.com/tenant/safeway/',
#  'https://www.netleaseadvisor.com/tenant/davita/',
#  'https://www.netleaseadvisor.com/tenant/fresenius-medical-care/',
#  'https://www.netleaseadvisor.com/tenant/cvs-pharmacy/',
#  'https://www.netleaseadvisor.com/tenant/rite-aid/',
#  'https://www.netleaseadvisor.com/tenant/walgreens/',
#  'https://www.netleaseadvisor.com/tenant/arbys/',
#  'https://www.netleaseadvisor.com/tenant/bojangles/',
#  'https://www.netleaseadvisor.com/tenant/burger-king/',
#  'https://www.netleaseadvisor.com/tenant/carls-jr/',
#  'https://www.netleaseadvisor.com/tenant/checkers/',
#  'https://www.netleaseadvisor.com/tenant/chick-fil-a/',
#  'https://www.netleaseadvisor.com/tenant/chipotle/',
#  'https://www.netleaseadvisor.com/tenant/churchs-chicken/',
#  'https://www.netleaseadvisor.com/tenant/dairy-queen/',
#  'https://www.netleaseadvisor.com/tenant/del-taco/',
#  'https://www.netleaseadvisor.com/tenant/dunkin-donuts/',
#  'https://www.netleaseadvisor.com/tenant/freddys-frozen-custard-steakburgers/',
#  'https://www.netleaseadvisor.com/tenant/hardees/',
#  'https://www.netleaseadvisor.com/tenant/jack-in-the-box/',
#  'https://www.netleaseadvisor.com/tenant/kfc/',
#  'https://www.netleaseadvisor.com/tenant/mcdonalds/',
#  'https://www.netleaseadvisor.com/tenant/panera-bread/',
#  'https://www.netleaseadvisor.com/tenant/pdq/',
#  'https://www.netleaseadvisor.com/tenant/pizza-hut/',
#  'https://www.netleaseadvisor.com/tenant/pollo-tropical/',
#  'https://www.netleaseadvisor.com/tenant/popeyes/',
#  'https://www.netleaseadvisor.com/tenant/raising-canes/',
#  'https://www.netleaseadvisor.com/tenant/sonic/',
#  'https://www.netleaseadvisor.com/tenant/starbucks-coffee/',
#  'https://www.netleaseadvisor.com/tenant/steak-n-shake/',
#  'https://www.netleaseadvisor.com/tenant/taco-bell/',
#  'https://www.netleaseadvisor.com/tenant/wendys/',
#  'https://www.netleaseadvisor.com/tenant/zaxbys/',
#  'https://www.netleaseadvisor.com/tenant/fedex/',
#  'https://www.netleaseadvisor.com/tenant/goodwill/',
#  'https://www.netleaseadvisor.com/tenant/la-fitness/',
#  'https://www.netleaseadvisor.com/tenant/mattress-firm/',
#  'https://www.netleaseadvisor.com/tenant/sherwin-williams/',
#  'https://www.netleaseadvisor.com/tenant/verizon/',
#  'https://www.netleaseadvisor.com/tenant/7-eleven/',
#  'https://www.netleaseadvisor.com/tenant/advance-auto-parts/',
#  'https://www.netleaseadvisor.com/tenant/aldi/',
#  'https://www.netleaseadvisor.com/tenant/applebees/',
#  'https://www.netleaseadvisor.com/tenant/arbys/',
#  'https://www.netleaseadvisor.com/tenant/autozone/',
#  'https://www.netleaseadvisor.com/tenant/bank-of-america/',
#  'https://www.netleaseadvisor.com/tenant/bbt-bank/',
#  'https://www.netleaseadvisor.com/tenant/bmo-harris-bank/',
#  'https://www.netleaseadvisor.com/tenant/bob-evans/',
#  'https://www.netleaseadvisor.com/tenant/bojangles/',
#  'https://www.netleaseadvisor.com/tenant/bridgestone/',
#  'https://www.netleaseadvisor.com/tenant/buffalo-wild-wings/',
#  'https://www.netleaseadvisor.com/tenant/burger-king/',
#  'https://www.netleaseadvisor.com/tenant/caliber-collision/',
#  'https://www.netleaseadvisor.com/tenant/carls-jr/',
#  'https://www.netleaseadvisor.com/tenant/chase-bank/',
#  'https://www.netleaseadvisor.com/tenant/checkers/',
#  'https://www.netleaseadvisor.com/tenant/chick-fil-a/',
#  'https://www.netleaseadvisor.com/tenant/chilis-grill-bar/',
#  'https://www.netleaseadvisor.com/tenant/chipotle/',
#  'https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/',
#  'https://www.netleaseadvisor.com/tenant/churchs-chicken/',
#  'https://www.netleaseadvisor.com/tenant/circle-k/',
#  'https://www.netleaseadvisor.com/tenant/cracker-barrel/',
#  'https://www.netleaseadvisor.com/tenant/cvs-pharmacy/',
#  'https://www.netleaseadvisor.com/tenant/dairy-queen/',
#  'https://www.netleaseadvisor.com/tenant/davita/',
#  'https://www.netleaseadvisor.com/tenant/del-taco/',
#  'https://www.netleaseadvisor.com/tenant/dennys/',
#  'https://www.netleaseadvisor.com/tenant/dollar-general/',
#  'https://www.netleaseadvisor.com/tenant/dollar-tree/',
#  'https://www.netleaseadvisor.com/tenant/dunkin-donuts/',
#  'https://www.netleaseadvisor.com/tenant/family-dollar/',
#  'https://www.netleaseadvisor.com/tenant/fedex/',
#  'https://www.netleaseadvisor.com/tenant/freddys-frozen-custard-steakburgers/',
#  'https://www.netleaseadvisor.com/tenant/fresenius-medical-care/',
#  'https://www.netleaseadvisor.com/tenant/goodwill/',
#  'https://www.netleaseadvisor.com/tenant/hardees/',
#  'https://www.netleaseadvisor.com/tenant/hobby-lobby/',
#  'https://www.netleaseadvisor.com/tenant/hooters/',
#  'https://www.netleaseadvisor.com/tenant/ihop/',
#  'https://www.netleaseadvisor.com/tenant/jack-in-the-box/',
#  'https://www.netleaseadvisor.com/tenant/jiffy-lube/',
#  'https://www.netleaseadvisor.com/tenant/kfc/',
#  'https://www.netleaseadvisor.com/tenant/la-fitness/',
#  'https://www.netleaseadvisor.com/tenant/mattress-firm/',
#  'https://www.netleaseadvisor.com/tenant/mcdonalds/',
#  'https://www.netleaseadvisor.com/tenant/napa-auto-parts/',
#  'https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/',
#  'https://www.netleaseadvisor.com/tenant/olive-garden/',
#  'https://www.netleaseadvisor.com/tenant/panera-bread/',
#  'https://www.netleaseadvisor.com/tenant/pdq/',
#  'https://www.netleaseadvisor.com/tenant/pizza-hut/',
#  'https://www.netleaseadvisor.com/tenant/pnc-bank/',
#  'https://www.netleaseadvisor.com/tenant/pollo-tropical/',
#  'https://www.netleaseadvisor.com/tenant/popeyes/',
#  'https://www.netleaseadvisor.com/tenant/raising-canes/',
#  'https://www.netleaseadvisor.com/tenant/red-lobster/',
#  'https://www.netleaseadvisor.com/tenant/rite-aid/',
#  'https://www.netleaseadvisor.com/tenant/ruby-tuesday/',
#  'https://www.netleaseadvisor.com/tenant/safeway/',
#  'https://www.netleaseadvisor.com/tenant/sheetz/',
#  'https://www.netleaseadvisor.com/tenant/sherwin-williams/',
#  'https://www.netleaseadvisor.com/tenant/sonic/',
#  'https://www.netleaseadvisor.com/tenant/starbucks-coffee/',
#  'https://www.netleaseadvisor.com/tenant/steak-n-shake/',
#  'https://www.netleaseadvisor.com/tenant/suntrust/',
#  'https://www.netleaseadvisor.com/tenant/taco-bell/',
#  'https://www.netleaseadvisor.com/tenant/td-bank/',
#  'https://www.netleaseadvisor.com/tenant/the-learning-experience/',
#  'https://www.netleaseadvisor.com/tenant/tractor-supply-co/',
#  'https://www.netleaseadvisor.com/tenant/verizon/',
#  'https://www.netleaseadvisor.com/tenant/walgreens/',
#  'https://www.netleaseadvisor.com/tenant/walmart/',
#  'https://www.netleaseadvisor.com/tenant/wawa/',
#  'https://www.netleaseadvisor.com/tenant/wells-fargo/',
#  'https://www.netleaseadvisor.com/tenant/wendys/',
#  'https://www.netleaseadvisor.com/tenant/zaxbys/',
#  '/bov-request',
#  'javascript:void(0);',
#  'http://www.spratings.com/en_US/understanding-ratings',
#  'https://www.moodys.com/Pages/amr002002.aspx',
#  '/contact',
#  'http://avisonyoung.com',
#  'mailto:mjvdesign@gmail.com?subject=Ref: netleaseadvisor.com',
#  'http://www.netleaseadvisor.com',
#  '/net-lease-101',
#  'javascript:void(0);',
#  '/contact',
#  '/bov-request',
#  'https://AvisonYoung.com',
#  'https://calkain.com/research',
#  'https://calkain.com/properties',
#  'mailto:research@calkain.com',
#  'http://calkain.com/contact/']

# %%
links[30:50]
# Out:
# ['https://www.netleaseadvisor.com/tenant/wells-fargo/',
#  'https://www.netleaseadvisor.com/tenant/hobby-lobby/',
#  'https://www.netleaseadvisor.com/tenant/tractor-supply-co/',
#  'https://www.netleaseadvisor.com/tenant/walmart/',
#  'https://www.netleaseadvisor.com/tenant/applebees/',
#  'https://www.netleaseadvisor.com/tenant/bob-evans/',
#  'https://www.netleaseadvisor.com/tenant/buffalo-wild-wings/',
#  'https://www.netleaseadvisor.com/tenant/chilis-grill-bar/',
#  'https://www.netleaseadvisor.com/tenant/cracker-barrel/',
#  'https://www.netleaseadvisor.com/tenant/dennys/',
#  'https://www.netleaseadvisor.com/tenant/hooters/',
#  'https://www.netleaseadvisor.com/tenant/ihop/',
#  'https://www.netleaseadvisor.com/tenant/olive-garden/',
#  'https://www.netleaseadvisor.com/tenant/red-lobster/',
#  'https://www.netleaseadvisor.com/tenant/ruby-tuesday/',
#  'https://www.netleaseadvisor.com/tenant/7-eleven/',
#  'https://www.netleaseadvisor.com/tenant/circle-k/',
#  'https://www.netleaseadvisor.com/tenant/sheetz/',
#  'https://www.netleaseadvisor.com/tenant/wawa/',
#  'https://www.netleaseadvisor.com/tenant/dollar-general/']

# %%
url2=('https://www.netleaseadvisor.com/tenant/wells-fargo/')

# %%
html2=requests.get(url2, headers=headers)

# %%
soup2=BS(html2.text, 'lxml')

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wells FargoNet Lease Advisor | Net Lease Advisor
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php" rel="pingback"/>
#   <!-- All in One SEO Pack 3.3.5 by Michael Torbert of Semper Fi Web Designob_start_detected [-1,-1] -->
#   <script class="aioseop-schema" type="application/ld+json">
#    {}
#   </script>
#   <link href="https://www.netleaseadvisor.com/tenant/wells-fargo/" rel="canonical"/>
#   <!-- All in One SEO Pack -->
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://www.netleaseadvisor.com/feed/" rel="alternate" title="Net Lease Advisor » Feed" type="application/rss+xml"/>
#   <link href="https://www.netleaseadvisor.com/comments/feed/" rel="alternate" title="Net Lease Advisor » Comments Feed" type="application/rss+xml"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.netleaseadvisor.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.3.2"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
#   </script>
#   <style type="text/css">
#    img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-includes/css/dist/block-library/style.min.css?ver=5.3.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.css?ver=5.3.2" id="jquery-ui-timepicker-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/css/dsc-style.css?ver=5.3.2" id="dsc-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/css/settings.css?ver=5.3.0.2" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="rs-plugin-settings-inline-css" type="text/css">
#    #rs-demo-id {}
#   </style>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.13-9993131" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=5.3.2" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/bootstrap.min.css?ver=5.3.2" id="lambda-bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/css/theme.min.css?ver=5.3.2" id="lambda-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/themes/lambda-child-theme/style.css?ver=5.3.2" id="lambda-child-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/lambda/stack-90.css?ver=5.3.2" id="lambda-theme-stack-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/css/wpb_wmca_style.css?ver=1.0" id="wpb_wmca_accordion_style-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="//www.google.com/jsapi?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/dynamic-stock-charts/js/dynamic-stock-charts.min.js?ver=1.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.tools.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.revolution.min.js?ver=5.3.0.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/Chart.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <link href="https://www.netleaseadvisor.com/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://www.netleaseadvisor.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="https://www.netleaseadvisor.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <link href="https://www.netleaseadvisor.com/tenant/bridgestone/" rel="prev" title="Bridgestone/Firestone"/>
#   <link href="https://www.netleaseadvisor.com/tenant/bob-evans/" rel="next" title="Bob Evans"/>
#   <meta content="WordPress 5.3.2" name="generator"/>
#   <link href="https://www.netleaseadvisor.com/?p=1202" rel="shortlink"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fwells-fargo%2F" rel="alternate" type="application/json+oembed"/>
#   <link href="https://www.netleaseadvisor.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.netleaseadvisor.com%2Ftenant%2Fwells-fargo%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#   <!-- This site is using AdRotate v5.4.2 Professional to display their advertisements - https://ajdg.solutions/products/adrotate-for-wordpress/ -->
#   <!-- AdRotate CSS -->
#   <style media="screen" type="text/css">
#    .g { margin:0px; padding:0px; overflow:hidden; line-height:1; zoom:1; }
# 	.g img { height:auto; }
# 	.g-col { position:relative; float:left; }
# 	.g-col:first-child { margin-left: 0; }
# 	.g-col:last-child { margin-right: 0; }
# 	@media only screen and (max-width: 480px) {
# 		.g-col, .g-dyn, .g-single { width:100%; margin-left:0; margin-right:0; }
# 	}
#   </style>
#   <!-- /AdRotate CSS -->
#   <style type="text/css">
#    .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#   </style>
#   <meta content="Powered by Visual Composer - drag and drop page builder for WordPress." name="generator"/>
#   <!--[if lte IE 9]><link rel="stylesheet" type="text/css" href="https://www.netleaseadvisor.com/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css" media="screen"><![endif]-->
#   <!--[if lte IE 8]><script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts/js/excanvas.compiled.js"></script><![endif]-->
#   <style>
#    /*wp_charts_js responsive canvas CSS override*/
#     			.wp_charts_canvas {
#     				width:100%!important;
#     				max-width:100%;
#     			}
#
#     			@media screen and (max-width:480px) {
#     				div.wp-chart-wrap {
#     					width:100%!important;
#     					float: none!important;
# 						margin-left: auto!important;
# 						margin-right: auto!important;
# 						text-align: center;
#     				}
#     			}
#   </style>
#   <meta content="Powered by Slider Revolution 5.3.0.2 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." name="generator"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-150x150.png" rel="icon" sizes="32x32"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="icon" sizes="192x192"/>
#   <link href="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/cropped-newfavicon2-300x300.png" name="msapplication-TileImage"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto:100,300,300italic,400,400italic,500,700,700italic%7CRoboto+Condensed:300,400,700%7CCutive:400%7CRoboto+Slab:100,300,400,700&amp;subset=latin,latin,latin,latin" rel="stylesheet" type="text/css"/>
#   <style media="screen" type="text/css">
#    .tenant-news-title {
#     font-family: Roboto, sans-serif;
#     font-weight: bold;
#     line-height: 18px;
#     margin-bottom: -4px;
# }
# span.tenant-news-date {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# span.tenant-news-source {
#     font-family: Roboto, sans-serif;
#     font-size: 12px;
#     font-weight: 400;
# }
# .eh-section {
#   margin-top: -15px;
# }
# .eh-title {
#     font-size: 18px;
#     font-weight: bold;
#     color: #F18F1F;
#     margin-top: -5px;
#     margin-bottom: 11px;
#     line-height: 20px;
# }
# .eh-bullets {
#  padding-bottom: 10px;
# }
# .eh-buttons a i {
#     margin-left: 0px !important;
#     padding-right: 5px !important;
#     font-size: 18px;
#     position: relative;
#     top: 1px;
# }
#
# .eh-buttons a {
# background: #00205B !important;
# font-weight: bold;
# margin-top: -3px;
# }
# .eh-buttons a:hover {
# background: #f18f1f !important;
# }
#
# /* Sidebar Contact Us button hover fix */
# .sidebar-contact-btn.btn.btn-block.btn-success:hover {
#     background-color: #f18f1f !important;
# }
# /* SCUBHF END */
#
# /* Sector Button Hover Fix */
# .selector-buttons:hover {
#     background-color: #f18f1f;
# }
# /* SBHF END */
#
# /* Credit Rating Nav item fix */
# .menu-item-523.active a:hover, .current-menu-item.menu-item-523 a:hover {
#     color: #00205B !important;
# }
# .menu-item-523.active a, .current-menu-item.menu-item-523 a{
#     color: #FFFFFF !important;
# }
# /* CRNIF END */
# .powered-by {
#     margin-left: -100px;
#     margin-bottom: -32px;
# }
#
# .dsc-loader {
#
#     position: relative !important;
#     top: 140px !important;
#
# }
#
# .wpcf7-mail-sent-ok {
#  color: #00205b !important;
#  font-weight: bold !important;
# font-size: 18px !important;
# }
#
# .btn {
#   border-radius: 5px !important;
# }
#
# .tenant-snapshot {
# 	color: #8C8279;
# 	font-size: 22px;
#         line-height: 38px;
# 	margin-top: 4px;
# 	margin-bottom: -1px;
#
# }
#
# .tenant-snapshot .tenant-name {
# 	color: #00205b;
# 	font-size: 40px;
# 	/* position: relative;
#         top: 6px; */
# }
#
# @media (max-width: 700px) {
#
# .tenant-logo {
#     height: 75px !important;
#     width: 100% !important;
#     margin-bottom: 25px !important;
# }
# .tenant-logo img {
#     position: inherit !important;
# }
#
# }
#
# /* Stock Chart Tooltip Style */
# .google-visualization-tooltip .dsc-tooltip caption {
#     font-size: 18px;
#     padding: 0;
# }
# .google-visualization-tooltip .dsc-tooltip td.label {
#     width: auto;
#     color: #F18F1F;
#     text-align: right;
#     padding-right: 5px;
# }
#
# /* Site Width Settings */
# @media (min-width: 1200px) and (max-width: 1414px){
#      .container {
#         width: 1200px !important;
#     }
#
# .featured-thumb a img {
#     width: 65px;
# }
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 17px;
#     font-weight: bold;
#     color: #8c8279;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-desc {
#     float: left;
#     margin-left: 10px;
#     line-height: 18px;
# }
# }
#
# @media (min-width: 1415px){
#     .container {
#         width: 1400px !important;
#     }
# }
# @media (min-width: 768px){
#     .container {
#         width: 100%;
#     }
# }
# a.tenant-detail-link.btn.btn-success, .sidebar-contact-btn {
#     background: #00205B !important;
#     border-radius: 5px !important;
#     font-size: 20px;
#     padding: 7px 30px;
#     margin: 20px auto;
#     font-weight: bold;
#     text-transform: uppercase;
# }
# a.tenant-detail-link.btn.btn-success:hover, .sidebar-contact-btn:hover {
#     background-color: #f18f1f !important;
# }
# .table-striped > tbody > tr:nth-child(odd) > td, .table-striped > tbody > tr:nth-child(odd) > th, .table-hover > tbody > tr:hover > td, .table-hover > tbody > tr:hover > th {
#     background: rgb(243, 243, 243);
# }
#
# section.section.tenant > .container > .row {
#     padding-bottom: 30px;
# }
#
# /* HOMEPAGE FEATURED TENANTS */
#
# .featured-single-wrapper {
#     width: 100%;
#     margin-top: 10px;
#     margin-bottom: 10px;
# }
#
# .featured-thumb {
#     float: left;
# }
#
# .featured-thumb a img {
#     width: 65px;
# }
#
# .featured-desc {
#     float: left;
#     margin-left: 15px;
#     line-height: 18px;
# }
#
# .featured-title {
#     font-family: Roboto, sans-serif;
#     font-size: 20px;
#     font-weight: bold;
#     color: #8C8279;
#     margin-bottom: 5px;
#     margin-top: 3px;
# }
# .featured-tenants > .post-title {
#     padding-top: 30px;
# }
#
# .featured-sector, .featured-cap {
#     font-size: 14px;
# }
#
# .featured-sector span, .featured-cap span {
#     font-weight: bold;
# }
#
# /* HEADER TAGLINE */
#
# .tagline {
# 	font-family: "Roboto Condensed" !important;
# 	font-weight: bold !important;
# 	font-size: 20px !important;
# 	color: #fff !important;
#         text-align: right !important;
# }
#
# /* SIDEBAR ACCORDION */
#
# .selector-buttons {
#     width: 100%;
#     margin: 30px 0;
#     padding: 10px;
#     font-size: 18px;
#     font-weight: bold;
#     background-color: #00205B;
# }
#
# @media (min-width: 992px) and (max-width: 1199px){
#
#     .selector-buttons {
#         font-size: 16px;
#         padding: 10px 5px;
#     }
#
# }
#
# .sidebar-toggle {
#     display:none;
# }
#
# @media (max-width: 991px) {
#     .col-md-3.sidebar .sidebar-collapse-control-btn {
#         position: absolute;
#         top: -1px;
#         left: -55px;
#         width: 55px;
#         height: 45px;
#         background-color: #00205B;
#         border-top-left-radius: 5px;
#         border-bottom-left-radius: 5px;
#     }
#     .sidebar-collapse-control-btn button.navbar-toggle.collapsed {
#         margin: 14px 15px;
#     }
#     .col-md-3.sidebar {
#         position: absolute;
#         top: -65px;
#         right: -300px;
#         width: 300px;
#         background-color: #f18f1f3;
#         border: 1px solid #f18f1f3;
#     }
#
#
# .sidebar-toggle {
#     display: block;
#     background: none !important;
#     margin: 14px 17px;
#     width: 22px;
#     height: 16px;
#     border: none;
#     transform: translate3d(0,0,0);
# }
#
# .sidebar-toggle .icon-bar:nth-child(1) {
#     top: 0;
# }
#
# .sidebar-toggle .icon-bar {
#     background-color: #fff;
# }
#
# .sidebar-toggle .icon-bar {
#     height: 1px;
#     width: 100%;
#     position: absolute;
#     left: 0;
#     margin-top: 0!important;
#     transition: all .3s;
#     -ms-transform-origin: 50% 50% 50%;
#     transform-origin: 50% 50% 50%;
#     transform: translate3d(0,0,0);
#     box-shadow: none;
# }
#
# .sidebar-toggle .icon-bar {
#     display: block;
#     width: 22px;
#     height: 1px;
#     border-radius: 1px;
# }
#
# .sidebar-toggle .icon-bar:nth-child(3) {
#     top: 100%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(2) {
#     opacity: 0;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(1) {
#     -ms-transform: rotate(45deg);
#     transform: rotate(45deg);
#     top: 50%;
# }
#
# .sidebar-toggle:not(.offscreen) .icon-bar:nth-child(3) {
#     top: 50%;
#     -ms-transform: rotate(-45deg);
#     transform: rotate(-45deg);
# }
#
# [class*="col-"].sidebar {
#     margin-bottom: auto !important;
#     padding-bottom: 0 !important;
# }
#
# .selector-buttons:hover {
#     background-color: #00205B;
# }
# }
#
# .ui-accordion h3 {
#    margin-top: 0;
#     margin-bottom: 0px;
#     padding-top: 1px;
#     padding-bottom: 1px;
#     padding-left: 3px;
# }
# .ui-accordion h3:hover {
#     background-color: #F18F1F;
#     color: #FFFFFF;
#     cursor: pointer;
# }
# li.accordion-list-item {
#     list-style: none;
#     border-bottom: 1px solid #84919f;
#     margin-left: 0px;
#     padding-left: 5px;
# }
# a li.accordion-list-item {
#     font-size: 16px;
# }
#
# li.accordion-list-item:hover {
#     background-color: #F18F1F;
#     color: #FFF;
#     cursor: pointer;
# }
#
# a li.accordion-list-item:hover {
#     color: #00205b;
#     cursor: pointer;
# }
#
# li.accordion-list-item.active-tenant {
#     background-color: #00205B;
#     padding-left: 5px;
#     margin-left: 0px;
# }
#
# a li.accordion-list-item.active-tenant {
#     color: #FFF;
# }
#
# /* AD AREAS */
# .banner-ad-wrapper {
#     padding: 50px 0;
#     text-align: center;
# }
#
# h3.sidebar-header {
#     text-transform: initial;
#     font-size: 24px;
#     border-bottom: 1px solid #84919f;
#     margin-bottom: 1px;
# }
# ul.tenant-list-ucr {
#     list-style: none;
#     padding: 0px;
#     margin: 0px;
# }
# li.tlucr-item {
#     border-bottom: 1px solid #84919f;
#     margin-left: 5px;
#     font-size: 16px;
# }
# .squeeze {
#     line-height: 1.5em !important;
# }
# /* SINGLE TENANT PAGE */
#
# .sidebar {
#     background-color: rgba(234, 233, 233, 0.55);
# }
#
# .tenant h1.post-title {
#     font-size: 35px;
#     font-weight: bold;
#     margin-top: 0px;
# }
#
# .header-updated-hr {
#     border-color: #F18F1F;
#     margin: -10px 0 3px;
# }
# .tenant-logo-home {
#     right: 15px;
#     top: 4px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# .tenant-logo {
#     right: 15px;
#     top: 8px;
#     position: absolute;
#     height: 75px;
#     width: 100%;
#     text-align: right;
# }
# @media (max-width: 991px){
#     .tenant-logo {
#         margin-right: 55px;
#     }
# }
# @media (max-width: 1414px){
#  .tenant h1.post-title {
#     font-size: 26px;
#     font-weight: bold;
#     margin-top: 40px;
# }
# }
# .tenant-logo  img {
#     max-width: 100%;
#     position: absolute;
#     bottom: 0;
#     right: 0;
# }
# .detail-box .detail-head {
#     background-color: #00205b;
#     color: #fff;
#     text-transform: normal;
#     font-size: 18px;
#     padding: 2px 10px;
#     text-align: right;
#     font-weight: 400;
# }
# .detail-large-data {
#     text-align: right;
#     font-size: 78px;
#     line-height: 85px;
#     font-weight: bold;
#     color: #f18f1f;
# }
# .detail-sm-desc {
#     font-size: 13px;
#     text-align: right;
#     clear: both;
# }
# .detail-box {
#     margin-bottom: 25px;
# }
# .detail-data-table tr td {
#     padding-top: 5px !important;
#     padding-bottom: 5px !important;
# }
# .tenant-url-link {
#     margin-bottom: 15px;
# }
# .tenant-url-link a {
#     color: #F18F1F;
#     font-size: 16px;
#     font-weight: bold;
# }
# .tenant-url-link a:hover {
#     text-decoration: underline;
# }
# .tenant-stock-chart {
#     margin: 15px 0 30px;
#     margin-top: -20px;
# }
# .dschart {
#       margin-top: -20px;
# }
# td.data-label {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#     font-weight: 400;
#     line-height: 18px !important;
# }
# td.data-data {
#     text-align: right;
#     width: 50%;
#     font-size: 14px;
#    font-weight: 400;
#     line-height: 18px !important;
# }
#
# .credit-rating td.data-label, .credit-rating td.data-data {
#     line-height: 22px !important;
#     width: 50%;
#     text-align: right;
#     font-size: 36px;
#     font-weight: bold;
#     color: #f18f1f;
#     padding: 10px 0 !important;
#  }
# .pros > h3, .cons > h3 {
#    padding-left: 11px;
# }
# .pro-item, .con-item, .eh-item {
#      font-size: 16px;
#      line-height: 20px;
#      margin-bottom: .8em;
# }
# .trend-info {
#     width: 33%;
#     float: left;
#     text-align: center;
#     margin-top: 8px;
# }
# .trend-year {
#     font-size: 18px;
#     color: #00205b;
#     margin-top: -15px;
# }
# .trend-rate {
#     font-size: 28px;
#     font-weight: bold;
#     color: #00205b;
# }
# .trend-image {
# width: 34%;
#     float: left;
#     text-align: center;
# }
# .tenant-description p {
#     font-size: 16px;
# }
# .tenant-description a {
# color: #f18f1f;
# }
# li.accordion-list-item.active {
#     background-color: #f18f1f;
# }
# li.accordion-list-item.active a {
#     color: #FFF;
# }
#
# /* MODAL */
# .modal-title {
#      font-size: 24px;
#      line-height: 24px;
# }
# .modal-body {
#     font-size: 14px;
#     line-height: 18px;
# }
# .modal-body a {
#     color: #f18f1f;
# }
# .modal-header {
#     border-bottom: 1px solid #f18f1f;
# }
# /* NET LEASE 101 */
# .caption-text {
# 	font-size: 16px;
# 	line-height: 1.4em;
# }
# .caption-head {
# 	font-family: Roboto Condensed, sans-serif;
# 	font-size: 21px;
# 	font-weight: bold;
# 	color: #00205b;
# }
#
# /*OTHER*/
# i {
#   color: #00205B !important;
# }
# .post-date {
#     font-size: 12px !important;
#     position: relative;
#     top: -2px !important;
#     font-style: italic;
#     color: #8c8279;
#     text-align: right;
# }
#
# #footer {
#   font-size: 14px;
# }
# .row:not(.sidebar-row){
#     overflow: hidden;
# }
#
# [class*="col-"].sidebar{
#     margin-bottom: -99999px;
#     padding-bottom: 99999px;
# }
#
# .subfooter {
#   text-align: center;
#   font-weight: 300;
# }
# .subfooter a {
#   font-weight: 400;
# }
#   </style>
#   <script type="text/javascript">
#    var lhnAccountN = "36965-1";
#     var lhnButtonN = 9229;
#     var lhnChatPosition = 'default';
#     var lhnInviteEnabled = 1;
#     var lhnWindowN = 0;
#     var lhnDepartmentN = 44047;
#     var lhnInviteN = 43001;
#   </script>
#   <noscript>
#    <style type="text/css">
#     .wpb_animate_when_almost_visible { opacity: 1; }
#    </style>
#   </noscript>
#  </head>
#  <body class="tenant-template-default single single-tenant postid-1202 wpb-js-composer js-comp-ver-5.0 vc_responsive">
#   <div class="pace-overlay">
#   </div>
#   <div class="menu navbar navbar-static-top header-logo-left-menu-below oxy-mega-menu navbar-sticky navbar-not-mobile-stuck text-none" id="masthead" role="banner">
#    <div class="logo-navbar container-logo">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle collapsed" data-target=".main-navbar" data-toggle="collapse" type="button">
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a class="navbar-brand" href="https://www.netleaseadvisor.com">
#        <img alt="Net Lease Advisor" src="https://www.netleaseadvisor.com/wp-content/uploads/2020/02/Net-Lease-Advisor-Logo-AY-Left-Justified.png"/>
#       </a>
#       <div class="logo-sidebar">
#        <div class="sidebar-widget widget_text" id="text-7">
#         <div class="textwidget">
#          <div class="powered-by">
#           Powered by
#          </div>
#          <div>
#           <a href="http://www.avisonyoung.com" rel="nofollow">
#            <img src="https://www.netleaseadvisor.com/wp-content/uploads/2020/02/AY_LOGO_WHITE_150w.png" width="75px"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="nav-container clearfix">
#      <nav class="collapse navbar-collapse main-navbar navbar-left" role="navigation">
#       <div class="menu-container">
#        <ul class="nav navbar-nav" id="menu-main">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-66" id="menu-item-66">
#          <a href="https://www.netleaseadvisor.com/">
#           HOME
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-728" id="menu-item-728">
#          <a href="https://www.netleaseadvisor.com/net-lease-101/">
#           NET LEASE 101
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-523" id="menu-item-523">
#          <a data-target="#521" data-toggle="modal" href="#">
#           CREDIT RATINGS
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-518" id="menu-item-518">
#          <a href="https://www.netleaseadvisor.com/contact/">
#           CONTACT
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="menu-sidebar">
#       </div>
#      </nav>
#     </div>
#    </div>
#   </div>
#   <div id="content" role="main">
#    <section class="section tenant">
#     <div class="container">
#      <div class="row">
#       <div class="col-md-9">
#        <p style="height: 45px;">
#        </p>
#        <article class="post-1202 tenant type-tenant status-publish has-post-thumbnail hentry sector-bank" id="post-1202">
#         <h1 class="post-title">
#          Wells Fargo TENANT OVERVIEW
#         </h1>
#         <div class="tenant-logo">
#          <img src="https://www.netleaseadvisor.com/wp-content/uploads/2018/04/wells_fargo_logo_2019.png"/>
#         </div>
#         <hr class="header-updated-hr"/>
#         <div class="post-date">
#          Updated: April 2, 2018
#         </div>
#         <div class="row">
#          <div class="col-md-8">
#           <div class="figure fade-in text-center figcaption-middle">
#            <img alt="" class="attachment-large size-large wp-post-image" height="364" sizes="(max-width: 800px) 100vw, 800px" src="https://www.netleaseadvisor.com/wp-content/uploads/2018/04/Wells_Fargo_Featured_NLA-800x364.png" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2018/04/Wells_Fargo_Featured_NLA-800x364.png 800w, https://www.netleaseadvisor.com/wp-content/uploads/2018/04/Wells_Fargo_Featured_NLA-300x136.png 300w, https://www.netleaseadvisor.com/wp-content/uploads/2018/04/Wells_Fargo_Featured_NLA-768x349.png 768w, https://www.netleaseadvisor.com/wp-content/uploads/2018/04/Wells_Fargo_Featured_NLA.png 1100w" width="800"/>
#           </div>
#           <div class="pros_cons row">
#            <div class="pros col-md-6">
#             <h3>
#              Pros
#             </h3>
#             <ul class="pros-list">
#              <li class="pro-item">
#               Investment grade tenant
#              </li>
#              <li class="pro-item">
#               NNN leases eliminate landlord responsibilities
#              </li>
#             </ul>
#            </div>
#            <div class="cons col-md-6">
#             <h3>
#              Cons
#             </h3>
#             <ul class="cons-list">
#              <li class="con-item">
#               Retail banking industry outlook on the number of physical locations required is evolving
#              </li>
#              <li class="con-item">
#               Low cap rates
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="eh-section">
#            <h2>
#             Earnings Highlights
#            </h2>
#            <div class="eh-title">
#             Earnings Summary
#            </div>
#            <div class="eh-bullets">
#             <ul class="eh-list">
#              <li class="eh-item">
#               Revenue of $21.6 B, down from $21.9 B
#              </li>
#              <li class="eh-item">
#               Net income of $5.9 B, compared with $5.1 B in Q1 2018
#              </li>
#              <li class="eh-item">
#               Average deposits of $1.3 T, down $35.1 B, or 3%
#              </li>
#             </ul>
#            </div>
#            <div class="eh-buttons">
#             <a class="btn btn-success eh_btn_1" href="https://www08.wellsfargomedia.com/assets/pdf/about/investor-relations/earnings/first-quarter-2019-earnings.pdf" target="_blank">
#              <i aria-hidden="true" class="fa fa-file-pdf-o">
#              </i>
#              Read Press Release
#             </a>
#            </div>
#           </div>
#           <div class="tenant-description">
#            <h2>
#             Tenant Description
#            </h2>
#            <p>
#             Wells Fargo (NYSE: WFC) is one of the largest retail banks in the US.
#             <br/>
#             <br/>
#             Wells Fargo’s stability and strength are a huge draw for net lease investors. Wells Fargo has strong investment grade credit, rated A- by S&amp;P and Aa2 by Moody’s. The Wells Fargo leases typically do not require any landlord responsibilities, making it a passive investment.  Most leases have rental increases built in during the primary term, during option periods, or both to provide a hedge against inflation.
#             <br/>
#             <br/>
#             Wells Fargo was found in 1852 by Henry Wells and William Fargo in the Gold Rush port of San Francisco. Today, Wells Fargo has a very large reach across the nation with over 8,300 locations and 13,000 ATMs. Wells Fargo has offices in 42 countries and serves one in three households in the US. Ranking 3rd in assets and in market value, Wells Fargo is a massive bank which offers many services to customers all over the world.
#             <br/>
#            </p>
#           </div>
#           <div class="tenant-url-link">
#            <a href="http://www.wellsfargo.com" target="_blank">
#             www.wellsfargo.com
#            </a>
#           </div>
#           <!-- TradingView Widget BEGIN -->
#           <script src="https://s3.tradingview.com/tv.js" type="text/javascript">
#           </script>
#           <script type="text/javascript">
#            new TradingView.widget({
#   "width": 665,
#   "height": 400,
#   "symbol": "WFC",
#   "interval": "W",
#   "timezone": "America/New_York",
#   "theme": "Light",
#   "style": "2",
#   "locale": "en",
#   "toolbar_bg": "rgba(255, 109, 0, 1)",
#   "enable_publishing": false,
#   "withdateranges": true,
#   "allow_symbol_change": true,
#   "details": true,
#   "hideideas": true
# });
#           </script>
#           <!-- TradingView Widget END -->
#          </div>
#          <div class="col-md-4">
#           <div class="detail-box">
#            <div class="detail-head">
#             Average Cap Rate
#            </div>
#            <div class="detail-large-data">
#             4.95%
#            </div>
#            <div class="detail-sm-desc">
#             12 mo avg with 10+ yr lease term
#            </div>
#           </div>
#           <div class="detail-box average-property-lease">
#            <div class="detail-head">
#             Average Property &amp; Lease
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                Average Sale Price
#               </td>
#               <td class="data-data">
#                $2,322,500
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                NOI
#               </td>
#               <td class="data-data">
#                $114,964
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                $/Square Foot
#               </td>
#               <td class="data-data">
#                $450 - $775
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Building SF
#               </td>
#               <td class="data-data">
#                3,000 - 5,000
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lot Size
#               </td>
#               <td class="data-data">
#                0.75 - 1.5 Acres
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Lease Term
#               </td>
#               <td class="data-data">
#                10 - 20 Years
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Escalations
#               </td>
#               <td class="data-data">
#                Varies
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Stock Symbol
#               </td>
#               <td class="data-data">
#                WFC
#               </td>
#              </tr>
#             </table>
#            </div>
#           </div>
#           <div class="detail-box credit-rating">
#            <div class="detail-head">
#             Credit Rating
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label">
#                S&amp;P
#               </td>
#               <td class="data-data">
#                A-
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label">
#                Moody's
#               </td>
#               <td class="data-data">
#                Aa2
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc" style="font-style: italic;">
#            </div>
#           </div>
#           <div class="detail-box average-cap-rate-trend">
#            <div class="detail-head">
#             Average Cap Rate Trend
#            </div>
#            <div class="cap-rate-trend-continer">
#             <div class="trend-info">
#              <div class="trend-left">
#               <div class="trend-rate">
#                5.23%
#               </div>
#               <div class="trend-year">
#                2016
#               </div>
#              </div>
#             </div>
#             <div class="trend-image">
#              <img src="/wp-content/plugins/post-accordion-widget-plugin/images/up.png"/>
#             </div>
#             <div class="trend-info">
#              <div class="trend-right">
#               <div class="trend-rate">
#                5.71%
#               </div>
#               <div class="trend-year">
#                2017
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="detail-sm-desc" style="padding-top: 5px;">
#             Rates reflect last 12 mos, short and long-term
#            </div>
#           </div>
#           <div class="detail-box recent-sales-comps">
#            <div class="detail-head">
#             Recent Sales Comps
#            </div>
#            <div class="detail-data-table">
#             <table class="table table-hover">
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Bluffton, SC
#               </td>
#               <td class="data-data">
#                4.94%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                San Bernardino, CA
#               </td>
#               <td class="data-data">
#                4.86%
#               </td>
#              </tr>
#              <tr>
#               <td class="data-label" style="text-align: left;">
#                Spanish Fort, AL
#               </td>
#               <td class="data-data">
#                5.50%
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="detail-sm-desc">
#            </div>
#           </div>
#           <div class="detail-box featured-net-lease-listing">
#            <div class="detail-head">
#             Featured Tenant Profiles
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/applebees/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/01/Applebees-Warrenton-VA-Calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/applebees/">
#                Applebee’s
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Casual Dining
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                6.97%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/cvs-pharmacy/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/02/CVS-Plantation-FL-calkain-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/cvs-pharmacy/">
#                CVS Pharmacy
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Pharmacy
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                5.46%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="featured-single-wrapper">
#             <div class="featured-thumb">
#              <a href="https://www.netleaseadvisor.com/tenant/the-learning-experience/">
#               <img src="https://www.netleaseadvisor.com/wp-content/uploads/2017/09/the-learning-experience-150x150.jpg"/>
#              </a>
#             </div>
#             <div class="featured-desc">
#              <div class="featured-title">
#               <a href="https://www.netleaseadvisor.com/tenant/the-learning-experience/">
#                The Learning Experience
#               </a>
#              </div>
#              <div class="featured-sector">
#               Sector:
#               <span class="value">
#                Educational
#               </span>
#              </div>
#              <div class="featured-cap">
#               Avg. Cap Rate:
#               <span class="value">
#                6.75%
#               </span>
#              </div>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </article>
#       </div>
#       <div class="col-md-3 sidebar">
#        <div class="sidebar-widget tax_accordion_widget_class" id="tax_accordion_widget-2">
#         <div class="sidebar-collapse-control-btn">
#          <button class="sidebar-toggle offscreen" type="button">
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </button>
#         </div>
#         <div class="container-fluid">
#          <div class="row">
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-sector">
#             SECTOR
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
#            <div class="btn btn-primary selector-buttons selector-alpha">
#             A-Z
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="accordion-sector" id="accordion-sector" style="display:none;">
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Automotive
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/advance-auto-parts/">
#             Advance Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/autozone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/autozone/">
#             AutoZone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bridgestone/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bridgestone/">
#             Bridgestone/Firestone
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/caliber-collision/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/caliber-collision/">
#             Caliber Collision
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/christian-brothers-automotive/">
#             Christian Brothers Automotive
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/jiffy-lube/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/jiffy-lube/">
#             Jiffy Lube
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/napa-auto-parts/">
#             Napa Auto Parts
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/oreilly-auto-parts/">
#             O’Reilly Auto Parts
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Bank
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/bank-of-america/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bank-of-america/">
#             Bank of America
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bbt-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bbt-bank/">
#             BB&amp;T Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bmo-harris-bank/">
#             BMO Harris Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/chase-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chase-bank/">
#             Chase Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/pnc-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/pnc-bank/">
#             PNC Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/suntrust/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/suntrust/">
#             SunTrust
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/td-bank/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/td-bank/">
#             TD Bank
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#             Wells Fargo
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Big Box
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/hobby-lobby/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hobby-lobby/">
#             Hobby Lobby
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/tractor-supply-co/">
#             Tractor Supply Co.
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/walmart/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/walmart/">
#             Walmart
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Casual Dining
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/applebees/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/applebees/">
#             Applebee’s
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/bob-evans/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/bob-evans/">
#             Bob Evans
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/buffalo-wild-wings/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/buffalo-wild-wings/">
#             Buffalo Wild Wings
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/chilis-grill-bar/">
#             Chili’s Grill &amp; Bar
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/cracker-barrel/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/cracker-barrel/">
#             Cracker Barrel
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/dennys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/dennys/">
#             Denny’s
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/hooters/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/hooters/">
#             Hooters
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/ihop/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/ihop/">
#             IHOP
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/olive-garden/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/olive-garden/">
#             Olive Garden
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/red-lobster/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/red-lobster/">
#             Red Lobster
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/ruby-tuesday/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/ruby-tuesday/">
#             Ruby Tuesday
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Convenience Store
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/7-eleven/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/7-eleven/">
#             7-Eleven
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/circle-k/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/circle-k/">
#             Circle K
#            </li>
#           </a>
# ...
#             Wawa
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wells-fargo/">
#             Wells Fargo
#            </li>
#           </a>
#           <a href="https://www.netleaseadvisor.com/tenant/wendys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/wendys/">
#             Wendy’s
#            </li>
#           </a>
#          </div>
#          <h3 style="border-bottom: 1px solid #0a2341;">
#           Z
#          </h3>
#          <div>
#           <a href="https://www.netleaseadvisor.com/tenant/zaxbys/">
#            <li class="accordion-list-item" data-id="https://www.netleaseadvisor.com/tenant/zaxbys/">
#             Zaxby’s
#            </li>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-10">
#         <div class="textwidget">
#          <a href="/bov-request">
#           <img src="http://netleaseadvisor.com/wp-content/uploads/2017/06/ad-calkain-bov.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-8">
#         <h3 class="sidebar-header">
#          Understanding Credit Ratings
#         </h3>
#         <div class="textwidget">
#          <ul class="tenant-list-ucr">
#           <li class="tlucr-item">
#            <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#             View Credit Rating Chart
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="http://www.spratings.com/en_US/understanding-ratings" rel="noopener noreferrer" target="_new">
#             Standard &amp; Poors
#            </a>
#           </li>
#           <li class="tlucr-item">
#            <a href="https://www.moodys.com/Pages/amr002002.aspx" rel="noopener noreferrer" target="_new">
#             Moody's
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="sidebar-widget widget_text" id="text-9">
#         <h3 class="sidebar-header">
#          Have a Research Project?
#         </h3>
#         <div class="textwidget">
#          <div class="squeeze">
#           Our experienced team provides unique insight to the net lease industry.  We can provide an in-depth analysis to a specific segment or assess an investment on your behalf.  Let us know your needs.
#          </div>
#          <a href="/contact">
#           <div class="sidebar-contact-btn btn btn-block btn-success">
#            Contact Us
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <footer id="footer" role="contentinfo">
#     <section class="section">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-6">
#          <div class="textwidget">
#           All logos are ©Copyright, ®Registered Trademarks and  courtesy of their respective companies, and are displayed in this website for the sole purpose of brand recognition in tenant labeling.
#           <br/>
#           ©2017-2020 netleaseadvisor.com,
#           <a href="http://avisonyoung.com" rel="nofollow">
#            Avison Young
#           </a>
#           . All Rights Reserved.
#           <br/>
#           2001 K Street, NW | Washington, DC 20006
#  Tel: 888.724.3244
#           <br/>
#           <span style="color:#a0a0a0; font-weight:bold;">
#            Developed by
#           </span>
#           <a href="mailto:mjvdesign@gmail.com?subject=Ref: netleaseadvisor.com">
#            <img alt="MJVdesign" border="0" src="/wp-content/uploads/2017/03/mjvdesign_logo_transp_light.png" style="margin-top: 2px; margin-left: -4px;" title="Email MJVdesign"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="section subfooter">
#      <div class="container">
#       <div class="row element-top-10 element-bottom-10 footer-columns-1">
#        <div class="col-sm-12">
#         <div class="sidebar-widget widget_text" id="text-11">
#          <div class="textwidget">
#           <a href="http://www.netleaseadvisor.com">
#            Home
#           </a>
#           |
#           <a href="/net-lease-101">
#            Net Lease 101
#           </a>
#           |
#           <a data-target="#521" data-toggle="modal" href="javascript:void(0);">
#            Credit Rating Chart
#           </a>
#           |
#           <a href="/contact">
#            Contact
#           </a>
#           |
#           <a href="/bov-request">
#            BOV Request
#           </a>
#           |
#           <a href="https://AvisonYoung.com" rel="nofollow">
#            Avison Young
#           </a>
#           |
#           <a href="https://calkain.com/research" rel="nofollow">
#            Research
#           </a>
#           |
#           <a href="https://calkain.com/properties" rel="nofollow">
#            Properties
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#    </footer>
#   </div>
#   <!-- Fixing the Back to top button -->
#   <script id="lhnscript" src="//www.livehelpnow.net/lhn/widgets/chatbutton/lhnchatbutton-current.min.js" type="text/javascript">
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#   ga('create', 'UA-4933828-6', 'auto');
#
#   ga('send', 'pageview');
#   </script>
#   <div class="modal fade" id="40" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        Subscribe
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        [mc4wp_form]
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="521" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-lg" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CREDIT RATING CHART
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        <img alt="Net Lease Advisor Credit Rating Chart" class="alignnone wp-image-1087 size-full" height="883" sizes="(max-width: 900px) 100vw, 900px" src="https://netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg" srcset="https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart.jpg 900w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-300x294.jpg 300w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-768x753.jpg 768w, https://www.netleaseadvisor.com/wp-content/uploads/2017/06/credit_rating_chart-800x785.jpg 800w" width="900"/>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="516" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-nm" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        CONTACT
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        For specific inquiries regarding this website or tenant information, please contact:
#       </p>
#       <p>
#        <strong>
#         Vinky Marolia
#        </strong>
#        <br/>
#        Research Analyst, Calkain Companies
#        <br/>
#        (571) 449-8146
#        <br/>
#        <a href="mailto:research@calkain.com">
#         research@calkain.com
#        </a>
#       </p>
#       <p>
#        For general inquiries or phone numbers and addresses for all of our office locations:
#        <br/>
#        <a href="http://calkain.com/contact/" target="_blank">
#         Contact Calkain
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/accordion.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/post-accordion-widget-plugin/controller.js?ver=9.9" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var click_object = {"ajax_url":"https:\/\/www.netleaseadvisor.com\/wp-admin\/admin-ajax.php"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/adrotate-pro/library/jquery.adrotate.clicktracker.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.netleaseadvisor.com\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.6" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":1,"isRTL":false});});
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/slider.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/jquery/ui/button.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-sliderAccess.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.cookie.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wpb-accordion-menu-or-category/assets/js/jquery.navgoco.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var mejsL10n = {"language":"en","strings":{"mejs.install-flash":"You are using a browser that does not have Flash player enabled or installed. Please turn on your Flash player plugin or download the latest version from https:\/\/get.adobe.com\/flashplayer\/","mejs.fullscreen-off":"Turn off Fullscreen","mejs.fullscreen-on":"Go Fullscreen","mejs.download-video":"Download Video","mejs.fullscreen":"Fullscreen","mejs.time-jump-forward":["Jump forward 1 second","Jump forward %1 seconds"],"mejs.loop":"Toggle Loop","mejs.play":"Play","mejs.pause":"Pause","mejs.close":"Close","mejs.time-slider":"Time Slider","mejs.time-help-text":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.","mejs.time-skip-back":["Skip back 1 second","Skip back %1 seconds"],"mejs.captions-subtitles":"Captions\/Subtitles","mejs.captions-chapters":"Chapters","mejs.none":"None","mejs.mute-toggle":"Mute Toggle","mejs.volume-help-text":"Use Up\/Down Arrow keys to increase or decrease volume.","mejs.unmute":"Unmute","mejs.mute":"Mute","mejs.volume-slider":"Volume Slider","mejs.video-player":"Video Player","mejs.audio-player":"Audio Player","mejs.ad-skip":"Skip ad","mejs.ad-skip-info":["Skip in 1 second","Skip in %1 seconds"],"mejs.source-chooser":"Source Chooser","mejs.stop":"Stop","mejs.speed-rate":"Speed Rate","mejs.live-broadcast":"Live Broadcast","mejs.afrikaans":"Afrikaans","mejs.albanian":"Albanian","mejs.arabic":"Arabic","mejs.belarusian":"Belarusian","mejs.bulgarian":"Bulgarian","mejs.catalan":"Catalan","mejs.chinese":"Chinese","mejs.chinese-simplified":"Chinese (Simplified)","mejs.chinese-traditional":"Chinese (Traditional)","mejs.croatian":"Croatian","mejs.czech":"Czech","mejs.danish":"Danish","mejs.dutch":"Dutch","mejs.english":"English","mejs.estonian":"Estonian","mejs.filipino":"Filipino","mejs.finnish":"Finnish","mejs.french":"French","mejs.galician":"Galician","mejs.german":"German","mejs.greek":"Greek","mejs.haitian-creole":"Haitian Creole","mejs.hebrew":"Hebrew","mejs.hindi":"Hindi","mejs.hungarian":"Hungarian","mejs.icelandic":"Icelandic","mejs.indonesian":"Indonesian","mejs.irish":"Irish","mejs.italian":"Italian","mejs.japanese":"Japanese","mejs.korean":"Korean","mejs.latvian":"Latvian","mejs.lithuanian":"Lithuanian","mejs.macedonian":"Macedonian","mejs.malay":"Malay","mejs.maltese":"Maltese","mejs.norwegian":"Norwegian","mejs.persian":"Persian","mejs.polish":"Polish","mejs.portuguese":"Portuguese","mejs.romanian":"Romanian","mejs.russian":"Russian","mejs.serbian":"Serbian","mejs.slovak":"Slovak","mejs.slovenian":"Slovenian","mejs.spanish":"Spanish","mejs.swahili":"Swahili","mejs.swedish":"Swedish","mejs.tagalog":"Tagalog","mejs.thai":"Thai","mejs.turkish":"Turkish","mejs.ukrainian":"Ukrainian","mejs.vietnamese":"Vietnamese","mejs.welsh":"Welsh","mejs.yiddish":"Yiddish"}};
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=4.2.13-9993131" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/mediaelement-migrate.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/","classPrefix":"mejs-","stretching":"responsive"};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/mediaelement/wp-mediaelement.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var oxyThemeData = {"navbarScrolledPoint":"30","navbarHeight":"100","navbarScrolled":"50","siteLoader":"off","menuClose":"off","scrollFinishedMessage":"No more items to load.","hoverMenu":{"hoverActive":true,"hoverDelay":200,"hoverFadeDelay":200}};
# /* ]]> */
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/themes/lambda/assets/js/theme.min.js?ver=1.0" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-content/plugins/wp-charts//js/functions.js?ver=5.3.2" type="text/javascript">
#   </script>
#   <script src="https://www.netleaseadvisor.com/wp-includes/js/wp-embed.min.js?ver=5.3.2" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
def Average_Cap_Rate(soup):
    return soup.find(string='Average Cap Rate').findNext('div').get_text()

# %%
Average_Cap_Rate(soup2)
# Out:
# '4.95%'

# %%
def Average_Sale_Price(soup):
    return soup.find(string='Average Sale Price').findNext('td').get_text()

# %%
Average_Sale_Price(soup2)
# Out:
# '$2,322,500'

# %%
def NOI_f(soup):
    return soup.find(string='NOI').findNext('td').get_text()

# %%
NOI_f(soup2)
# Out:
# '$114,964'

# %%
def d_Square_Foot(soup):
    return soup.find(string='$/Square Foot').findNext('td').get_text()

# %%
d_Square_Foot(soup2)
# Out:
# '$450 - $775'

# %%
def Building_SF(soup):
    return soup.find(string='Building SF').findNext('td').get_text()

# %%
Building_SF(soup2)
# Out:
# '3,000 - 5,000'

# %%
def Lot_Size(soup):
    return soup.find(string='Building SF').findNext('td').get_text()

# %%
Lot_Size(soup2)
# Out:
# '3,000 - 5,000'

# %%
def Lease_Term(soup):
    return soup.find(string='Lease Term').findNext('td').get_text()

# %%
Lease_Term(soup2)
# Out:
# '10 - 20 Years'

# %%
def Escalations_f(soup):
    return soup.find(string='Escalations').findNext('td').get_text()

# %%
Escalations_f(soup2)
# Out:
# 'Varies'

# %%
def Stock_Symbol(soup):
    return soup.find(string='Stock Symbol').findNext('td').get_text()

# %%
Stock_Symbol(soup2)
# Out:
# 'WFC'

# %%
def S_P(soup):
    return soup.find(string='S&P').findNext('td').get_text()

# %%
S_P(soup2)
# Out:
# 'A-'

# %%
def Moodys_f(soup):
    return soup.find(string='Moody\'s').findNext('td').get_text()

# %%
Moodys_f(soup2)
# Out:
# 'Aa2'

# %%
def Trend_1Y(soup):
    return soup.findAll('div',{'class':'trend-rate'})[0].get_text()

# %%
Trend_1Y(soup2)
# Out:
# '5.23%'

# %%
def Trend_2Y(soup):
    return soup.findAll('div',{'class':'trend-rate'})[1].get_text()

# %%
Trend_2Y(soup2)
# Out:
# '5.71%'

# %%
AverageCapRates=[]
AverageSalePrices=[]
NOI=[]
DollarSquareFoot=[]
BuildingSF=[]
LotSize=[]
LeaseTerm=[]
Escalations=[]
StockSymbol=[]
SP=[]
Moodys=[]
Trend1Y=[]
Trend2Y=[]

# %%
for link in links[30:50]:
    html=requests.get(link)
    soup=BS(html.text,'lxml')
    AverageCapRates.append(Average_Cap_Rate(soup))
    AverageSalePrices.append(Average_Sale_Price(soup))
    NOI.append(NOI_f(soup))
    DollarSquareFoot.append(d_Square_Foot(soup))
    BuildingSF.append(Building_SF(soup))
    LotSize.append(Lot_Size(soup))
    LeaseTerm.append(Lease_Term(soup))
    Escalations.append(Escalations_f(soup))
    StockSymbol.append(Stock_Symbol(soup))
    SP.append(S_P(soup))
    Moodys.append(Moodys_f(soup))
    Trend1Y.append(Trend_1Y(soup))
    Trend2Y.append(Trend_2Y(soup))

# %%
QSR_df=pd.DataFrame({'Average Cap Rates' : AverageCapRates,'Average Sale Prices' : AverageSalePrices,'NOI':NOI,\
                     '$/Square Foot' : DollarSquareFoot,'Building SF' : BuildingSF,'Lot Size':LotSize,\
                     'Lease Term' : LeaseTerm,'Escalations' : Escalations,'Stock Symbol':StockSymbol,'S&P' : SP,\
                     'Moodys' : Moodys,'Trend1Y':Trend1Y,'Trend2Y':Trend2Y,})

# %%
QSR_df
# Out:
#    Average Cap Rates Average Sale Prices       NOI  $/Square Foot  \
# 0              4.95%          $2,322,500  $114,964    $450 - $775
# 1              6.36%          $7,253,111  $461,298    $100 - $150
# 2              6.38%          $3,997,605  $255,047           $190
# 3              5.44%         $11,441,125  $622,397     $60 - $300
# 4              6.97%          $2,476,874  $178,219    $500 - $620
# 5              5.70%          $2,254,526  $125,895    $375 - $450
# 6              6.93%          $2,694,782  $195,916    $385 - $490
# 7              5.49%          $2,941,333  $161,479           $500
# 8              4.95%          $3,095,083  $167,227    $257 - $343
# 9              5.95%          $2,351,969  $139,942    $475 - $625
# 10             6.55%          $2,764,815  $181,095    $460 - $615
# 11             6.18%          $2,596,800  $160,482    $475 - $600
# 12             5.75%          $2,770,477  $161,390    $345 - $370
# 13             6.07%          $4,447,092  $269,938    $550 - $700
# 14             6.61%          $1,913,333  $125,131    $382 - $478
# 15             5.10%          $2,979,318  $151,945  $850 - $1,100
# 16             5.76%          $1,989,996  $114,624  $450 - $1,000
# 17             5.36%          $2,814,036  $156,399           $433
# 18             4.73%          $4,876,738  $231,529    $810 - $975
# 19             6.81%          $1,342,205   $95,591    $135 - $150
#
#                   Building SF                   Lot Size     Lease Term  \
# 0               3,000 - 5,000              3,000 - 5,000  10 - 20 Years
# 1             49,000 - 75,000            49,000 - 75,000   5 - 15 Years
# 2                      20,000                     20,000       15 Years
# 3            38,000 - 182,000           38,000 - 182,000        20 Year
# 4               4,000 - 5,000              4,000 - 5,000  15 - 20 Years
# 5               5,000 - 6,000              5,000 - 6,000       20 Years
# 6               5,500 - 7,000              5,500 - 7,000         Varies
# 7                       6,000                      6,000       20 Years
# 8              9,000 - 12,000             9,000 - 12,000       10 Years
# 9   3,800 - 5,000 square feet  3,800 - 5,000 square feet  15 - 20 Years
# 10              4,500 - 6,000              4,500 - 6,000       20 Years
# 11              4,000 - 5,000              4,000 - 5,000  20 - 25 Years
# 12              7,500 - 8,000              7,500 - 8,000         Varies
# 13              7,000 - 9,000              7,000 - 9,000  20 - 25 Years
# 14              4,000 - 5,000              4,000 - 5,000       20 Years
# 15              2,500 - 3,500              2,500 - 3,500  10 - 20 Years
# 16              2,000 - 4,500              2,000 - 4,500  10 - 15 Years
# 17                      6,500                      6,500  15 - 20 Years
# 18              5,000 - 6,000              5,000 - 6,000       20 Years
# 19             9,000 - 10,000             9,000 - 10,000  10 - 15 Years
#
#                    Escalations Stock Symbol  S&P Moodys Trend1Y Trend2Y
# 0                       Varies          WFC   A-    Aa2   5.23%   5.71%
# 1            In Option Periods          N/A  N/A    N/A   6.07%   6.38%
# 2        5 - 10% Every 5 Years         TSCO  N/A    N/A   6.38%   7.15%
# 3   5 - 10% at Renewal Options          WMT   AA    Aa2   5.52%   5.84%
# 4                       Varies          DIN  N/A    N/A    6.84   7.16%
# 5                  2% Annually          N/A  N/A    N/A   5.57%   5.73%
# 6              10% every 5 yrs          N/A  N/A    N/A    6.03    6.95
# 7                       Varies          EAT  BB+    Ba1   6.35%   5.49%
# 8            10% Every 5 Years         CBRL  N/A    N/A   6.00%   5.22%
# 9        5 - 10% Every 5 Years         DENN  N/A    N/A   6.08%   5.62%
# 10                      Varies          N/A  N/A    N/A   7.49%   6.15%
# 11                      Varies          DIN  N/A    N/A   6.23%   6.38%
# 12               1.5% Annually          DRI  BBB   Baa2   5.28%   6.24%
# 13                 2% Annually          N/A  N/A     B3   6.12%   5.65%
# 14           10% every 5 years          N/A  N/A    N/A   6.13%   6.68%
# 15           10% Every 5 Years          N/A  AA-   Baa1   5.50%   5.37%
# 16       5 - 10% Every 5 Years          N/A  BBB   Baa2   6.52%   5.47%
# 17        10% in Option Period          N/A  N/A    N/A   5.70%   5.20%
# 18       7 - 10% Every 5 Years          N/A  N/A    N/A   4.72%   4.74%
# 19           In Option Periods           DG  BBB   Baa2   7.09%   7.08%

# %%
QSR_df.to_csv('example_Net_Lease_Advisor.csv', sep=',')
